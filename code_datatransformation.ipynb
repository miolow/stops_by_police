# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np

from geopy.geocoders import Nominatim
from shapely.geometry import Point

from geopy.extra.rate_limiter import RateLimiter
import numpy as np  # Import NumPy

from geopy.exc import GeocoderTimedOut
from geopy.geocoders import Nominatim  # Replace with your geocoding service if different
import time

# %%
# Adjust the display settings to see the full content of the column
pd.set_option('display.max_colwidth', None)

# Set display option to show all rows
pd.set_option('display.max_rows', None)

# %%
# print columns function
def col_printing(df):
    for i, col in enumerate(df):
        print(i, col)

# %% [markdown]
# # Loading in the Census Tract shapefiles

# %%
# path to shapefile
shapefile_census = 'C:/Users/blah/blah/Documents/Data/Misc/dcdneighborhoods/WI_Tract/tl_2023_55_tract.shp'

# load the shapefile into geodataframe
tract_gdf = gpd.read_file(shapefile_census)

tract_gdf.to_csv('tract_gdf.csv', index = False)

# %%
col_printing(tract_gdf)
# Out:
# 0 STATEFP
# 1 COUNTYFP
# 2 TRACTCE
# 3 GEOID
# 4 GEOIDFQ
# 5 NAME
# 6 NAMELSAD
# 7 MTFCC
# 8 FUNCSTAT
# 9 ALAND
# 10 AWATER
# 11 INTPTLAT
# 12 INTPTLON
# 13 geometry

# %%
# rename the GEOIDFQ to ID
tract_gdf = tract_gdf.rename(columns = {'GEOIDFQ' : 'ID'})

# start by reprojecting to EPSG: 26916, this allows us to calculate the area
tract_gdf = tract_gdf.to_crs(epsg=26916) 

# Add a new column for the area in square meters
tract_gdf['tract_area_sq_m'] = tract_gdf.geometry.area

# %% [markdown]
# # Loading in the Neighborhood shapefiles

# %%
# path to shapefile
shapefile_neigh = 'C:/Users/blah/blah/Documents/Data/Misc/dcdneighborhoods/DCDNeighborhoods.shp'

# load the shapefile into geodataframe
neighbor_gdf = gpd.read_file(shapefile_neigh)

# display the first few rows of dataframe
print(neighbor_gdf.head())

# start by reprojecting to EPSG: 3857, this allows us to calculate the area
neighbor_gdf = neighbor_gdf.to_crs(epsg=26916)  
# Add a new column for the area in square meters
neighbor_gdf['neigh_area_sq_m'] = neighbor_gdf.geometry.area

neighbor_gdf.to_csv('neighbor_gdf.csv', index = False)
# Out:
#    OBJECTID    Neighborho  SYMBOL    Neighbor_1    SHAPE_STAr    SHAPE_STLe  \
# 0         3     NEW COELN       1     New Coeln  5.723546e+06   9615.009330
# 1         4    SOUTHPOINT       4    Southpoint  1.073536e+07  14415.135317
# 2         5  TOWN OF LAKE       2  Town Of Lake  2.737191e+07  25967.630731
# 3         6    TIPPECANOE       4    Tippecanoe  2.645802e+07  33503.757162
# 4         7    MORGANDALE       2    Morgandale  2.952580e+07  22330.698849
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             geometry
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  POLYGON ((2557219.136 345963.367, 2557096.316 345961.701, 2557071.531 348141.052, 2559712.478 348176.003, 2559702.669 348013.684, 2559700.241 347953.238, 2559696.985 347639.502, 2559699.241 347312.188, 2559703.12 347177.758, 2559709.154 347072.602, 2559720.075 346957.858, 2559727.914 346896.661, 2559736.026 346828.042, 2559739.875 346729.119, 2559745.264 346541.666, 2559743.724 346401.943, 2559739.875 346230.271, 2559727.173 346066.298, 2559721.399 346010.486, 2559721.379 346010.267, 2557219.136 345963.367))
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           POLYGON ((2551560.369 364404.596, 2551571.075 363714.613, 2551572.513 363085.474, 2551578.648 362415.406, 2551581.328 362122.62, 2551584.738 361750.196, 2551248.878 361745.501, 2550644.194 361737.05, 2550008.013 361728.157, 2549659.582 361723.475, 2549531.886 361721.501, 2549027.128 361714.446, 2549027.13 361714.265, 2547728.211 361679.463, 2547572.631 361675.287, 2547567.559 362076.398, 2546978.063 362049.193, 2547007.709 362095.7, 2547322.609 362428.237, 2547727.32 362855.616, 2547726.918 362855.993, 2547472.445 363094.12, 2547473.721 363095.47, 2547527.613 363152.494, 2547527.61 363152.766, 2547525.266 363351.066, 2547688.311 363356.794, 2547688.669 363356.806, 2547687.504 363459.864, 2547682.696 363885.424, 2547679.727 364148.276, 2547678.76 364148.244, 2547680.958 364226.654, 2547684.183 364341.756, 2547744.576 364343.781, 2548281.744 364362.265, 2548569.887 364371.466, 2548986.443 364385.437, 2549344.082 364388.036, 2549660.575 364390.402, 2549979.456 364392.784, 2550294.313 364395.137, 2550613.318 364397.521, 2551067.688 364402.342, 2551560.369 364404.596))
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      POLYGON ((2561331.826 360618.72, 2561630.792 360402.379, 2561825.838 360272.521, 2562144.574 360064.402, 2562135.319 360588.69, 2562379.484 360586.685, 2562667.843 360592.214, 2562968.3 360597.976, 2563039.297 360590.023, 2563072.197 360583.778, 2563102.212 360580.767, 2563132.675 360580.277, 2563294.6 360583.994, 2563625.466 360591.587, 2563625.85 360591.601, 2563651.326 359351.45, 2563652.926 359240.171, 2564858.135 358588.206, 2564874.757 357535.647, 2564887.6 356722.47, 2562883.715 356673.05, 2562541.18 356664.601, 2562215.93 356656.579, 2561550.807 356641.232, 2561542.824 356988.896, 2561535.655 357301.051, 2561528.646 357606.248, 2561165.492 357596.858, 2560835.877 357588.335, 2560508.651 357579.874, 2560178.122 357571.329, 2559849.034 357562.821, 2559518.995 357554.287, 2559541.246 356594.864, 2559154.641 356587.134, 2558428.89 356573.388, 2557567.207 356555.391, 2556920 356542.45, 2556905.748 357442.837, 2556903.102 357591.059, 2556877.4 359233.86, 2556874.265 359353.445, 2556861.86 359892.77, 2556846.598 360539.88, 2557173.722 360557.376, 2557492.589 360559.605, 2557714.039 360561.151, 2557850.157 360560.283, 2557989.937 360563.08, 2558149.131 360564.191, 2558484.954 360566.537, 2558806.726 360568.785, 2559126.734 360571.023, 2559469.805 360573.419, 2559532.105 360572.68, 2559781.457 360575.502, 2560110.103 360584.663, 2561331.826 360618.72))
# 3  POLYGON ((2565482.603 364545.356, 2565482.729 364533.35, 2565440.575 364532.572, 2565440.497 364544.579, 2564924.155 364535.061, 2564931.803 364019.785, 2564934.126 363863.267, 2565405.041 363872.203, 2565407.831 363711.696, 2565418.471 363101.254, 2565588.847 363104.438, 2565590.001 363037.758, 2565605.089 362165.275, 2565607.127 362047.431, 2565607.13 362047.298, 2565653.53 362048.171, 2565658.111 361717.683, 2565610.379 361716.738, 2565618.567 361386.099, 2565453.357 361382.936, 2565115.958 361376.477, 2565103.99 361873.769, 2564863.182 361869.247, 2564872.836 361371.669, 2564873.856 361319.056, 2564623.778 361313.561, 2564491.273 361310.649, 2564491.288 361309.883, 2564494.665 361137.672, 2564495.668 361086.533, 2564812.393 361093.679, 2564815.247 360946.433, 2564498.106 360953.608, 2564498.458 360935.482, 2563915.518 360950.366, 2563910.865 361177.46, 2564198.406 361183.851, 2564195.384 361334.058, 2564188.552 361673.558, 2564184.881 361855.986, 2563600.211 361839.658, 2563625.85 360591.601, 2563625.466 360591.587, 2563294.6 360583.994, 2563132.675 360580.277, 2563102.212 360580.767, 2563072.197 360583.778, 2563039.297 360590.023, 2562968.3 360597.976, 2562667.843 360592.214, 2562379.484 360586.685, 2562135.319 360588.69, 2562144.574 360064.402, 2561825.838 360272.521, 2561630.792 360402.379, 2561331.826 360618.72, 2560110.103 360584.663, 2559781.457 360575.502, 2559532.105 360572.68, 2559469.805 360573.419, 2559126.734 360571.023, 2558806.726 360568.785, 2558484.954 360566.537, 2558149.131 360564.191, 2557989.937 360563.08, 2557850.157 360560.283, 2557714.039 360561.151, 2557492.589 360559.605, 2557173.722 360557.376, 2556846.598 360539.88, 2556830.731 361212.684, 2556815.753 361847.741, 2557142.108 361855.426, 2557192.497 361856.612, 2557393.301 361861.292, 2557466.882 361863.073, 2557824.47 361871.673, 2557862.913 361872.437, 2557917.654 361873.526, 2558043.338 361876.648, 2558108.048 361878.171, 2558466.655 361886.614, 2558776.583 361893.913, 2559020.055 361899.646, 2559097.604 361901.472, 2559442.674 361909.685, 2559429.742 362552.276, 2559422.358 362912.045, 2559415.99 363236.847, 2559414.763 363297.875, 2559412.138 363419.809, 2559409.069 363581, 2559402.776 363894.018, 2559389.188 364561.086, 2559696.23 364567.981, 2559879.8 364572.124, 2560122.834 364577.584, 2560430.666 364584.557, 2560830.961 364593.591, 2561143.462 364600.645, 2561453.073 364607.633, 2561769.42 364614.772, 2562088.543 364621.975, 2562418.204 364629.729, 2562755.64 364639.776, 2563083.368 364648.52, 2563422.843 364653.381, 2563739.756 364660.842, 2564067.161 364668.55, 2564396.19 364676.297, 2564756.09 364684.77, 2565058.961 364690.241, 2565358.912 364695.656, 2565658.865 364701.072, 2565958.813 364706.889, 2566065.082 364708.407, 2566264.408 364712.3, 2566357.764 364713.544, 2566472.165 364563.597, 2566162.153 364557.882, 2565482.603 364545.356))
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 POLYGON ((2557897.351 366326.967, 2557877.499 366251.719, 2557789.632 366003.948, 2557678.104 365636.486, 2557630.607 365409.919, 2557573.119 365157.132, 2557537.106 364928.996, 2557371.977 364869.544, 2557213.766 364810.907, 2556994.991 364750.445, 2556776.921 364704.046, 2556779.694 364486.632, 2556784.23 364177.908, 2556788.822 363838.427, 2556815.753 361847.741, 2554792.052 361796.099, 2554203.063 361781.745, 2553876.724 361777.623, 2553558.043 361773.809, 2553236.28 361769.959, 2552897.855 361765.909, 2552559.104 361761.855, 2552239.635 361758.033, 2551920.656 361754.215, 2551584.738 361750.196, 2551581.328 362122.62, 2551578.648 362415.406, 2551572.513 363085.474, 2551571.075 363714.613, 2551560.369 364404.596, 2551559.971 365068.921, 2551559.576 365730.497, 2551559.182 366390.282, 2551558.851 367049.551, 2551883.124 367051.355, 2552201.393 367053.127, 2552518.748 367054.893, 2552808.031 367056.502, 2553115.635 367058.214, 2553431.152 367059.97, 2553792.069 367061.979, 2554156.349 367063.959, 2554481.588 367073.204, 2554807.533 367082.468, 2555130.885 367091.659, 2555454.868 367100.868, 2555778.603 367110.071, 2556102.165 367119.267, 2556425.604 367128.46, 2556751.006 367137.711, 2556940.736 367142.676, 2556998.476 367135.012, 2557055.473 367117.091, 2557119.246 367095.552, 2557175.623 367067.199, 2557218.092 367036.987, 2557260.444 366999.405, 2557293.755 366963.397, 2557323.188 366920.232, 2557354.227 366866.257, 2557398.369 366779.778, 2557436.649 366706.505, 2557476.78 366631.686, 2557522.968 366564.702, 2557573.237 366507.741, 2557622.575 366462.546, 2557666.708 366429.1, 2557706.065 366402.959, 2557728.525 366391.067, 2557778.992 366364.276, 2557846.112 366340.833, 2557897.351 366326.967))

# %% [markdown]
# # Load in Demographic Details
# S2301 - population, labor, unemployment, employment rate
# S0101 - age x gender
# B03002 - not hispanic
# B02001 - race

# %% [markdown]
# ## 2023 files
# merged_23_df is the merged file for all of the 2023 data

# %%
# read the files for 2023
df_S2301_emp = pd.read_csv("C:/Users/blah/blah/Data/Misc/dcdneighborhoods/ACSDT5Y2023.S2301-Transposed.csv")
df_S0101_age = pd.read_csv("C:/Users/blah/blah/Documents/Data/Misc/dcdneighborhoods/ACSDT5Y2023.S0101-Transposed.csv")
df_B03002_nothis = pd.read_csv("C:/Users/blah/blah/Documents/Data/Misc/dcdneighborhoods/ACSDT5Y2023.B03002-Data.csv")
df_B02001_race = pd.read_csv("C:/Users/blah/blah/Documents/Data/Misc/dcdneighborhoods/ACSDT5Y2023.B02001-Data.csv")

# rename totalpop in df_S0101_age to totalpop_agedf
df_S0101_age = df_S0101_age.rename(columns = {'totalpop' : 'totalpop_agedf'})

# rename totalpop in df_B02001_race to totalpop_racedf
df_B02001_race = df_B02001_race.rename(columns = {'totalpop' : 'totalpop_racedf'})

merge1_df = pd.merge(df_B02001_race, df_S0101_age, on = 'ID', how = 'inner')
merged_23_df = pd.merge(merge1_df, df_B03002_nothis, on = 'ID', how = 'inner')
merged_23_df = pd.merge(merged_23_df, df_S2301_emp, on = 'ID', how = 'inner')

# %% [markdown]
# ## 2022 files (acs5yr_2022_merged.csv)

# %%
merged_22_df = pd.read_csv("C:/Users/blah/blah/Documents/Data/Misc/dcdneighborhoods/acs5yr_2022_merged.csv")

# rename id to ID
merged_22_df = merged_22_df.rename(columns = {'id' : 'ID', 'totalpop' : 'totalpop_2022'})

# %% [markdown]
# ### Combine 2022 and 2023 dataframes together

# %%
# Merge DataFrames on the 'ID' column
combined_df = pd.merge(merged_22_df, merged_23_df, on='ID', suffixes=('_2022', '_2023'))

# totalpop_agedf and totalpop_racedf are the same so we drop totalpop_racedf and rename totalpop_agedf into totalpop2023
combined_df = combined_df.drop(columns=['totalpop_racedf'])
combined_df = combined_df.rename(columns = {'totalpop_agedf' : 'totalpop_2023'})

combined_df.to_csv('combined_nocrime.csv', index = False)

# %%
col_printing(combined_df)
# Out:
# 0 ID
# 1 tractfips
# 2 geographicareaname
# 3 totalpop_2022
# 4 white_2022
# 5 black_2022
# 6 ai_an_2022
# 7 asian_2022
# 8 nh_opi_2022
# 9 otherrace_2022
# 10 two_or_more_race_2022
# 11 total_under5_2022
# 12 total_5to9_2022
# 13 total10to14_2022
# 14 total_15to19_2022
# 15 total_20to24_2022
# 16 total_25to29_2022
# 17 total_30to34_2022
# 18 total_35to39_2022
# 19 total_40to44_2022
# 20 total_45to49_2022
# 21 total_50to54_2022
# 22 total_55to59_2022
# 23 total_60to64_2022
# 24 total_65to69_2022
# 25 total_70to74_2022
# 26 total_75to79_2022
# 27 total_80to84_2022
# 28 total_85andolder_2022
# 29 total_under18_2022
# 30 total_16andover_2022
# 31 total_over18_2022
# 32 totalmale_2022
# 33 male_under5_2022
# 34 male_5to9_2022
# 35 male_10to14_2022
# 36 male_15to19_2022
# 37 male_20to24_2022
# 38 male_25to29_2022
# 39 male_30to34_2022
# 40 male_35to39_2022
# 41 male_40to44_2022
# 42 male_45to49_2022
# 43 male_50to54_2022
# 44 male_55to59_2022
# 45 male_60to64_2022
# 46 male_65to69_2022
# 47 male_70to74_2022
# 48 male_75to79_2022
# 49 male_80to84_2022
# 50 male_85andover_2022
# 51 male_under18_2022
# 52 male_16andover_2022
# 53 male_over18_2022
# 54 totalfemale_2022
# 55 female_under5_2022
# 56 female_5to9_2022
# 57 female_10to14_2022
# 58 female_15to19_2022
# 59 female_20to24_2022
# 60 female_25to29_2022
# 61 female_30to34_2022
# 62 female_35to39_2022
# 63 female_40to44_2022
# 64 female_45to49_2022
# 65 female_50to54_2022
# 66 female_55to59_2022
# 67 female_60to64_2022
# 68 female_65to69_2022
# 69 female_70to74_2022
# 70 female_75to79_2022
# 71 female_80to84_2022
# 72 female_85andover_2022
# 73 female_under18_2022
# 74 female_16andover_2022
# 75 female_over18_2022
# 76 total_nothispanic_2022
# 77 white_not_hisp_2022
# 78 black_not_hisp_2022
# 79 ai_an_not_hisp_2022
# 80 asian_not_hisp_2022
# 81 nh_opi_not_hisp_2022
# 82 otherrace_not_hisp_2022
# 83 two_or_more_race_not_hisp_2022
# 84 total_hispanic_2022
# 85 hispanic_white_2022
# 86 hispanic_black_2022
# 87 hispanic_ai_an_2022
# 88 hispanic_asian_2022
# 89 hispanic_nh_opi_2022
# 90 hispanic_otherrace_2022
# 91 hispanic_two_or_more_race_2022
# 92 tract_id_str
# 93 tract_id_int
# 94 summarizedareainsquaremiles
# 95 areainsquaremiles
# 96 districtnumber
# 97 percentarea
# 98 _merge
# 99 Geographic Area Name_x
# 100 white_2023
# 101 black_2023
# 102 ai_an_2023
# 103 asian_2023
# 104 nh_opi_2023
# 105 otherrace_2023
# 106 two_or_more_race_2023
# 107 Label (Grouping)
# 108 totalpop_2023
# 109 total_under5_2023
# 110 total_5to9_2023
# 111 total10to14_2023
# 112 total_15to19_2023
# 113 total_20to24_2023
# 114 total_25to29_2023
# 115 total_30to34_2023
# 116 total_35to39_2023
# 117 total_40to44_2023
# 118 total_45to49_2023
# 119 total_50to54_2023
# 120 total_55to59_2023
# 121 total_60to64_2023
# 122 total_65to69_2023
# 123 total_70to74_2023
# 124 total_75to79_2023
# 125 total_80to84_2023
# 126 total_85andolder_2023
# 127 total_under18_2023
# 128 total_16andover_2023
# 129 total_over18_2023
# 130 totalmale_2023
# 131 male_under5_2023
# 132 male_5to9_2023
# 133 male_10to14_2023
# 134 male_15to19_2023
# 135 male_20to24_2023
# 136 male_25to29_2023
# 137 male_30to34_2023
# 138 male_35to39_2023
# 139 male_40to44_2023
# 140 male_45to49_2023
# 141 male_50to54_2023
# 142 male_55to59_2023
# 143 male_60to64_2023
# 144 male_65to69_2023
# 145 male_70to74_2023
# 146 male_75to79_2023
# 147 male_80to84_2023
# 148 male_85andover_2023
# 149 male_under18_2023
# 150 male_16andover_2023
# 151 male_over18_2023
# 152 totalfemale_2023
# 153 female_under5_2023
# 154 female_5to9_2023
# 155 female_10to14_2023
# 156 female_15to19_2023
# 157 female_20to24_2023
# 158 female_25to29_2023
# 159 female_30to34_2023
# 160 female_35to39_2023
# 161 female_40to44_2023
# 162 female_45to49_2023
# 163 female_50to54_2023
# 164 female_55to59_2023
# 165 female_60to64_2023
# 166 female_65to69_2023
# 167 female_70to74_2023
# 168 female_75to79_2023
# 169 female_80to84_2023
# 170 female_85andover_2023
# 171 female_under18_2023
# 172 female_16andover_2023
# 173 female_over18_2023
# 174 Geographic Area Name_y
# 175 total_nothispanic_2023
# 176 white_not_hisp_2023
# 177 black_not_hisp_2023
# 178 ai_an_not_hisp_2023
# 179 asian_not_hisp_2023
# 180 nh_opi_not_hisp_2023
# 181 otherrace_not_hisp_2023
# 182 two_or_more_race_not_hisp_2023
# 183 total_hispanic_2023
# 184 hispanic_white_2023
# 185 hispanic_black_2023
# 186 hispanic_ai_an_2023
# 187 hispanic_asian_2023
# 188 hispanic_nh_opi_2023
# 189 hispanic_otherrace_2023
# 190 hispanic_two_or_more_race_2023
# 191 Tract
# 192 Population
# 193 Labor Force Participation Rate
# 194 Employment/Population Ratio
# 195 Unemployment rate

# %% [markdown]
# ### Calculating the Average Scores for Demographic Details 2022 and 2023

# %%
# Identify columns ending with '_2022' and '_2023'
columns_2022 = [col for col in combined_df.columns if col.endswith('_2022')]
columns_2023 = [col for col in combined_df.columns if col.endswith('_2023')]

# Ensure the same base columns exist in both years
common_bases = [col.replace('_2022', '') for col in columns_2022 if col.replace('_2022', '_2023') in columns_2023]

for base in common_bases:
    col_2022 = f'{base}_2022'
    col_2023 = f'{base}_2023'

    # Get the data types of the actual columns from the DataFrame
    column_types_2022 = combined_df[col_2022].dtype
    column_types_2023 = combined_df[col_2023].dtype

    print(f"Data type of {col_2022}: {column_types_2022}")
    print(f"Data type of {col_2023}: {column_types_2023}")
# Out:
# Data type of totalpop_2022: float64
# Data type of totalpop_2023: int64
# Data type of white_2022: float64
# Data type of white_2023: object
# Data type of black_2022: float64
# Data type of black_2023: object
# Data type of ai_an_2022: float64
# Data type of ai_an_2023: int64
# Data type of asian_2022: float64
# Data type of asian_2023: int64
# Data type of nh_opi_2022: float64
# Data type of nh_opi_2023: int64
# Data type of otherrace_2022: float64
# Data type of otherrace_2023: object
# Data type of two_or_more_race_2022: float64
# Data type of two_or_more_race_2023: object
# Data type of total_under5_2022: float64
# Data type of total_under5_2023: int64
# Data type of total_5to9_2022: float64
# Data type of total_5to9_2023: int64
# Data type of total10to14_2022: float64
# Data type of total10to14_2023: int64
# Data type of total_15to19_2022: float64
# Data type of total_15to19_2023: int64
# Data type of total_20to24_2022: float64
# Data type of total_20to24_2023: int64
# Data type of total_25to29_2022: float64
# Data type of total_25to29_2023: int64
# Data type of total_30to34_2022: float64
# Data type of total_30to34_2023: int64
# Data type of total_35to39_2022: float64
# Data type of total_35to39_2023: int64
# Data type of total_40to44_2022: float64
# Data type of total_40to44_2023: int64
# Data type of total_45to49_2022: float64
# Data type of total_45to49_2023: int64
# Data type of total_50to54_2022: float64
# Data type of total_50to54_2023: int64
# Data type of total_55to59_2022: float64
# Data type of total_55to59_2023: int64
# Data type of total_60to64_2022: float64
# Data type of total_60to64_2023: int64
# Data type of total_65to69_2022: float64
# Data type of total_65to69_2023: int64
# Data type of total_70to74_2022: float64
# Data type of total_70to74_2023: int64
# Data type of total_75to79_2022: float64
# Data type of total_75to79_2023: int64
# Data type of total_80to84_2022: float64
# Data type of total_80to84_2023: int64
# Data type of total_85andolder_2022: float64
# Data type of total_85andolder_2023: int64
# Data type of total_under18_2022: float64
# Data type of total_under18_2023: int64
# Data type of total_16andover_2022: float64
# Data type of total_16andover_2023: int64
# Data type of total_over18_2022: float64
# Data type of total_over18_2023: int64
# Data type of totalmale_2022: float64
# Data type of totalmale_2023: int64
# Data type of male_under5_2022: float64
# Data type of male_under5_2023: int64
# Data type of male_5to9_2022: float64
# Data type of male_5to9_2023: int64
# Data type of male_10to14_2022: float64
# Data type of male_10to14_2023: int64
# Data type of male_15to19_2022: float64
# Data type of male_15to19_2023: int64
# Data type of male_20to24_2022: float64
# Data type of male_20to24_2023: int64
# Data type of male_25to29_2022: float64
# Data type of male_25to29_2023: int64
# Data type of male_30to34_2022: float64
# Data type of male_30to34_2023: int64
# Data type of male_35to39_2022: float64
# Data type of male_35to39_2023: int64
# Data type of male_40to44_2022: float64
# Data type of male_40to44_2023: int64
# Data type of male_45to49_2022: float64
# Data type of male_45to49_2023: int64
# Data type of male_50to54_2022: float64
# Data type of male_50to54_2023: int64
# Data type of male_55to59_2022: float64
# Data type of male_55to59_2023: int64
# Data type of male_60to64_2022: float64
# Data type of male_60to64_2023: int64
# Data type of male_65to69_2022: float64
# Data type of male_65to69_2023: int64
# Data type of male_70to74_2022: float64
# Data type of male_70to74_2023: int64
# Data type of male_75to79_2022: float64
# Data type of male_75to79_2023: int64
# Data type of male_80to84_2022: float64
# Data type of male_80to84_2023: int64
# Data type of male_85andover_2022: float64
# Data type of male_85andover_2023: int64
# Data type of male_under18_2022: float64
# Data type of male_under18_2023: int64
# Data type of male_16andover_2022: float64
# Data type of male_16andover_2023: int64
# Data type of male_over18_2022: float64
# Data type of male_over18_2023: int64
# Data type of totalfemale_2022: float64
# Data type of totalfemale_2023: int64
# Data type of female_under5_2022: float64
# Data type of female_under5_2023: int64
# Data type of female_5to9_2022: float64
# Data type of female_5to9_2023: int64
# Data type of female_10to14_2022: float64
# Data type of female_10to14_2023: int64
# Data type of female_15to19_2022: float64
# Data type of female_15to19_2023: int64
# Data type of female_20to24_2022: float64
# Data type of female_20to24_2023: int64
# Data type of female_25to29_2022: float64
# Data type of female_25to29_2023: int64
# Data type of female_30to34_2022: float64
# Data type of female_30to34_2023: int64
# Data type of female_35to39_2022: float64
# Data type of female_35to39_2023: int64
# Data type of female_40to44_2022: float64
# Data type of female_40to44_2023: int64
# Data type of female_45to49_2022: float64
# Data type of female_45to49_2023: int64
# Data type of female_50to54_2022: float64
# Data type of female_50to54_2023: int64
# Data type of female_55to59_2022: float64
# Data type of female_55to59_2023: int64
# Data type of female_60to64_2022: float64
# Data type of female_60to64_2023: int64
# Data type of female_65to69_2022: float64
# Data type of female_65to69_2023: int64
# Data type of female_70to74_2022: float64
# Data type of female_70to74_2023: int64
# Data type of female_75to79_2022: float64
# Data type of female_75to79_2023: int64
# Data type of female_80to84_2022: float64
# Data type of female_80to84_2023: int64
# Data type of female_85andover_2022: float64
# Data type of female_85andover_2023: int64
# Data type of female_under18_2022: float64
# Data type of female_under18_2023: int64
# Data type of female_16andover_2022: float64
# Data type of female_16andover_2023: int64
# Data type of female_over18_2022: float64
# Data type of female_over18_2023: int64
# Data type of total_nothispanic_2022: float64
# Data type of total_nothispanic_2023: object
# Data type of white_not_hisp_2022: float64
# Data type of white_not_hisp_2023: object
# Data type of black_not_hisp_2022: float64
# Data type of black_not_hisp_2023: object
# Data type of ai_an_not_hisp_2022: float64
# Data type of ai_an_not_hisp_2023: int64
# Data type of asian_not_hisp_2022: float64
# Data type of asian_not_hisp_2023: int64
# Data type of nh_opi_not_hisp_2022: float64
# Data type of nh_opi_not_hisp_2023: int64
# Data type of otherrace_not_hisp_2022: float64
# Data type of otherrace_not_hisp_2023: int64
# Data type of two_or_more_race_not_hisp_2022: float64
# Data type of two_or_more_race_not_hisp_2023: int64
# Data type of total_hispanic_2022: float64
# Data type of total_hispanic_2023: object
# Data type of hispanic_white_2022: float64
# Data type of hispanic_white_2023: object
# Data type of hispanic_black_2022: float64
# Data type of hispanic_black_2023: int64
# Data type of hispanic_ai_an_2022: float64
# Data type of hispanic_ai_an_2023: int64
# Data type of hispanic_asian_2022: float64
# Data type of hispanic_asian_2023: int64
# Data type of hispanic_nh_opi_2022: float64
# Data type of hispanic_nh_opi_2023: int64
# Data type of hispanic_otherrace_2022: float64
# Data type of hispanic_otherrace_2023: object
# Data type of hispanic_two_or_more_race_2022: float64
# Data type of hispanic_two_or_more_race_2023: object

# %%
# some columns are not in numeric format and here, we are converting them to numeric
colstoconvert = ['white_2023', 'black_2023', 'otherrace_2023', 
                 'two_or_more_race_2023', 'total_nothispanic_2023',
                 'white_not_hisp_2023', 'black_not_hisp_2023', 'total_hispanic_2023',
                 'hispanic_white_2023', 'hispanic_otherrace_2023',
                 'hispanic_two_or_more_race_2023'
                 ]

# loop through each column in the list
for col in colstoconvert:
    # remove commas and convert to numeric
    combined_df[col] = combined_df[col].str.replace(',', '', regex=True)
    combined_df[col] = pd.to_numeric(combined_df[col], errors='coerce')

# %%
def calculate_yearly_averages(df, base_columns):
    """
    Calculate averages between 2022 and 2023 values and add them to the original DataFrame.
    
    Parameters:
    df (pandas.DataFrame): Input DataFrame containing *_2022 and *_2023 columns
    base_columns (list): List of base column names without year suffixes
    
    Returns:
    pandas.DataFrame: Original DataFrame with new averaged columns added
    """
    # Create a copy of the original DataFrame to avoid modifying it directly
    result_df = df.copy()
    
    for col in base_columns:
        col_2022 = f"{col}_2022"
        col_2023 = f"{col}_2023"
        
        # Calculate average and store in new column
        # The new column will be named {col}_avg
        result_df[f"{col}_avg"] = df[[col_2022, col_2023]].mean(axis=1)
    
    return result_df

# Use the function
combined_df = calculate_yearly_averages(combined_df, common_bases)

# %%
# rename combined_df['tractfips'] to GEOID
combined_df = combined_df.rename(columns = {'tractfips' : 'GEOID'})

# %%
combined_df.to_csv("combined_df.csv", index = False)

# %% [markdown]
# ### Add the geometry columns of our census tract file

# %%
# CENSUS TRACT SHAPEFILE
shapefile_pathtract = 'C:/Users/blah/blah/Documents/Data/Misc/dcdneighborhoods/WI_Tract/tl_2023_55_tract.shp'
tract_gdf = gpd.read_file(shapefile_pathtract)
tract_gdf.to_csv('tract_gdf.csv', index = False)
print(tract_gdf.crs)

# NEIGHBORHOOD TRACT SHAPEFILE
shapefile_pathneigh = 'C:/Users/blah/blah/Documents/Data/Misc/dcdneighborhoods/DCDNeighborhoods.shp'
neighborhood_gdf = gpd.read_file(shapefile_pathneigh)
neighborhood_gdf.to_csv('neighborhood_gdf.csv', index = False)
print(tract_gdf.crs)

neighborhood_gdf = neighborhood_gdf.to_crs("EPSG:26916")
tract_gdf = tract_gdf.to_crs("EPSG:26916")
# Out:
# EPSG:4269
# EPSG:4269

# %% [markdown]
# #### Merging tract_gdf with combined_df

# %%
tract_gdf['GEOID'] = tract_gdf['GEOID'].astype('int64')

combined_acs5yr_map_df = pd.merge(combined_df, tract_gdf, on = 'GEOID', how = 'inner')

acs5yr_2022_2023_avgonly = combined_acs5yr_map_df.copy()

acs5yr_2022_2023_avgonly.to_csv("acs5yr_2022_2023_avgonly.csv", index = False)

# %% [markdown]
# ##### Retain specific columns for acs5yr_2022_2023_avgonly (remove the _2022 and _2023 columns) and calling this new dataframe, map_acs5yr

# %%
# specify columns to keep
column_indices = list(range(0, 3)) + list(range(92, 98)) + list(range(191, 298))

# Subset the DataFrame to keep only the specified columns
map_acs5yr = acs5yr_2022_2023_avgonly.iloc[:, column_indices]

map_acs5yr.to_csv('map_acs5yr.csv', index = False)

# %% [markdown]
# ## Merging our map_acs5yr file with neighborhood shapefile (neighborhood_gdf) to find tract and neighborhood intersections

# %%
print(neighborhood_gdf.crs)
# Out:
# EPSG:32054

# %%
# Create GeoDataFrame with proper CRS
map_acs5yr = gpd.GeoDataFrame(
    map_acs5yr,
    geometry='geometry',  # Ensure you're using the correct column for geometry
    crs="EPSG:26916"  # Set the CRS to EPSG:26916 (NAD83 / Wisconsin South)
)

neighborhood_gdf = neighborhood_gdf.to_crs("EPSG:26916")

# %%
# Perform spatial intersection to find where tracts and neighborhoods overlap
intersection = gpd.overlay(map_acs5yr, neighborhood_gdf, how='intersection')

# Calculate the area of intersection for each tract-neighborhood pair
intersection['tractneigh_intersection_area'] = intersection.geometry.area

# Group by neighborhood to see which tracts are in each neighborhood
neighborhood_tracts = intersection.groupby('Neighborho').agg({
    'GEOID': list,  # List of tract IDs
    'NAME': list,   # List of tract names
    'tractneigh_intersection_area': list  # Areas of intersection
}).reset_index()

neighborhood_tracts.to_csv('neighborhood_tracts.csv', index = False)

# %% [markdown]
# # Figuring out the Neighborhood Demographic Details

# %%
# clean up the three columns that are in percentages
# Replace '-' with NaN
for col in ['Labor Force Participation Rate', 'Employment/Population Ratio', 'Unemployment rate']:
    map_acs5yr[col] = map_acs5yr[col].replace('-', np.nan)

# Remove '%' and convert columns to numeric
for col in ['Labor Force Participation Rate', 'Employment/Population Ratio', 'Unemployment rate']:
    map_acs5yr[col] = map_acs5yr[col].str.rstrip('%').astype(float)

    # fill in NaN for empty elements
    map_acs5yr = map_acs5yr.replace('', np.nan)

avg_cols = ['Labor Force Participation Rate', 'Employment/Population Ratio', 'Unemployment rate']
# Replace '-' with NaN and then convert to float
map_acs5yr[avg_cols] = map_acs5yr[avg_cols].replace('-', np.nan).replace('%', '', regex=True).astype(float)

# %%
print(map_acs5yr.crs)
# Out:
# EPSG:26916

# %%
def estimate_neighborhood_demographics(tract_gdf, neighborhood_gdf, demographic_columns, rate_columns):
    """
    Estimate neighborhood demographics based on overlapping census tracts.
    
    Parameters:
    tract_gdf: GeoDataFrame with census tract data including demographics and geometry
    neighborhood_gdf: GeoDataFrame with neighborhood boundaries
    demographic_columns: List of demographic column names to estimate (raw demographic data)
    rate_columns: List of rate column names to estimate (percentage columns like Labor Force Participation Rate, etc.)
    
    Returns:
    GeoDataFrame with estimated neighborhood demographics
    """
    # Create copies to avoid modifying original data
    tracts = tract_gdf.copy()
    neighborhoods = neighborhood_gdf.copy()
    
    # Calculate tract areas for later proportion calculations
    tracts['tract_area'] = tracts.geometry.area
    
    # Perform spatial intersection
    intersections = gpd.overlay(tracts, neighborhoods, how = 'intersection')
    
    # Calculate the area of each intersection
    intersections['overlap_area'] = intersections.geometry.area
    
    # Calculate what proportion of each tract falls in each neighborhood
    intersections['tract_proportion'] = intersections['overlap_area'] / intersections['tract_area']
    
    # Initialize a dictionary to store results
    demographic_estimates = {}
    
    # Calculate weighted demographics for each neighborhood
    for col in demographic_columns:
        # Multiply demographic values by the proportion of tract area
        intersections[f'{col}_weighted'] = intersections[col] * intersections['tract_proportion']
        
        # Sum up the weighted values for each neighborhood
        demographic_estimates[col] = intersections.groupby('Neighborho')[f'{col}_weighted'].sum()
    
    # Handle rate columns differently (calculate average of rates within each neighborhood)
    for rate_col in rate_columns:
        # Take the weighted average of the rate columns (not the raw values)
        intersections[f'{rate_col}_avg'] = intersections[rate_col]
        
        # Calculate the average rate for each neighborhood (sum of rates / number of tracts in that neighborhood)
        demographic_estimates[rate_col] = intersections.groupby('Neighborho')[f'{rate_col}_avg'].mean()
    
    # Create results DataFrame
    results = pd.DataFrame(demographic_estimates)
    
    # Merge results back with original neighborhood data
    final_results = neighborhoods.merge(results, left_on='Neighborho', right_index=True)
    
    return final_results

def verify_estimates(original_tracts, estimated_neighborhoods, demographic_columns, rate_columns):
    """
    Verify that total populations roughly match between tracts and neighborhoods, 
    and handle verification for columns with percentage values by checking averages.
    """
    print("Verification of estimates:")
    print("-" * 50)
    
    # Verify demographic columns (non-percentage columns)
    for col in demographic_columns:
        tract_total = original_tracts[col].sum()
        neighborhood_total = estimated_neighborhoods[col].sum()
        difference_pct = ((neighborhood_total - tract_total) / tract_total) * 100
        
        print(f"\n{col}:")
        print(f"Total from tracts: {tract_total:,.0f}")
        print(f"Total from neighborhoods: {neighborhood_total:,.0f}")
        print(f"Difference: {difference_pct:,.2f}%")
    
    # Verify rate columns (percentage columns like Labor Force Participation Rate, etc.)
    for rate_col in rate_columns:
        tract_avg = original_tracts[rate_col].mean()
        neighborhood_avg = estimated_neighborhoods[rate_col].mean()
        difference_pct = ((neighborhood_avg - tract_avg) / tract_avg) * 100
        
        print(f"\n{rate_col}:")
        print(f"Average from tracts: {tract_avg:,.2f}%")
        print(f"Average from neighborhoods: {neighborhood_avg:,.2f}%")
        print(f"Difference: {difference_pct:,.2f}%")

# %%
demographic_cols = ['Population', 'totalpop_avg', 'white_avg', 'black_avg', 'asian_avg', 'ai_an_avg', 'nh_opi_avg', 'otherrace_avg', 
    'two_or_more_race_avg', 'total_under5_avg', 'total_5to9_avg', 'total10to14_avg', 
    'total_15to19_avg', 'total_20to24_avg', 'total_25to29_avg', 'total_30to34_avg', 
    'total_35to39_avg', 'total_40to44_avg', 'total_45to49_avg', 'total_50to54_avg', 
    'total_55to59_avg', 'total_60to64_avg', 'total_65to69_avg', 'total_70to74_avg', 
    'total_75to79_avg', 'total_80to84_avg', 'total_85andolder_avg', 'total_under18_avg', 
    'total_16andover_avg', 'total_over18_avg', 'totalmale_avg', 'male_under5_avg', 
    'male_5to9_avg', 'male_10to14_avg', 'male_15to19_avg', 'male_20to24_avg', 'male_25to29_avg',
    'male_30to34_avg', 'male_35to39_avg', 'male_40to44_avg', 'male_45to49_avg', 'male_50to54_avg',
    'male_55to59_avg', 'male_60to64_avg', 'male_65to69_avg', 'male_70to74_avg', 'male_75to79_avg',
    'male_80to84_avg', 'male_85andover_avg', 'male_under18_avg', 'male_16andover_avg', 'male_over18_avg',
    'totalfemale_avg', 'female_under5_avg', 'female_5to9_avg', 'female_10to14_avg', 'female_15to19_avg',
    'female_20to24_avg', 'female_25to29_avg', 'female_30to34_avg', 'female_35to39_avg', 'female_40to44_avg',
    'female_45to49_avg', 'female_50to54_avg', 'female_55to59_avg', 'female_60to64_avg', 'female_65to69_avg',
    'female_70to74_avg', 'female_75to79_avg', 'female_80to84_avg', 'female_85andover_avg', 'female_under18_avg',
    'female_16andover_avg', 'female_over18_avg', 'total_nothispanic_avg', 'white_not_hisp_avg', 'black_not_hisp_avg',
    'ai_an_not_hisp_avg', 'asian_not_hisp_avg', 'nh_opi_not_hisp_avg', 'otherrace_not_hisp_avg', 'two_or_more_race_not_hisp_avg',
    'total_hispanic_avg', 'hispanic_white_avg', 'hispanic_black_avg', 'hispanic_ai_an_avg', 'hispanic_asian_avg',
    'hispanic_nh_opi_avg', 'hispanic_otherrace_avg', 'hispanic_two_or_more_race_avg']

rate_cols = ['Labor Force Participation Rate', 'Employment/Population Ratio', 'Unemployment rate']

# Calculate estimates
neighborhood_estimates = estimate_neighborhood_demographics(
    map_acs5yr,    # your tract GeoDataFrame
    neighborhood_gdf,  # your neighborhood GeoDataFrame
    demographic_cols, rate_cols   # list of columns to estimate
)

# Verifying estimates
verified_numbers = verify_estimates(map_acs5yr, neighborhood_estimates, demographic_cols, rate_cols)
# Out:
# Verification of estimates:
# --------------------------------------------------
#
# Population:
# Total from tracts: 692,047
# Total from neighborhoods: 551,126
# Difference: -20.36%
#
# totalpop_avg:
# Total from tracts: 884,260
# Total from neighborhoods: 713,014
# Difference: -19.37%
#
# white_avg:
# Total from tracts: 384,864
# Total from neighborhoods: 260,910
# Difference: -32.21%
#
# black_avg:
# Total from tracts: 306,655
# Total from neighborhoods: 290,155
# Difference: -5.38%
#
# asian_avg:
# Total from tracts: 39,757
# Total from neighborhoods: 31,292
# Difference: -21.29%
#
# ai_an_avg:
# Total from tracts: 5,400
# Total from neighborhoods: 4,489
# Difference: -16.88%
#
# nh_opi_avg:
# Total from tracts: 141
# Total from neighborhoods: 110
# Difference: -21.94%
#
# otherrace_avg:
# Total from tracts: 56,418
# Total from neighborhoods: 48,492
# Difference: -14.05%
#
# two_or_more_race_avg:
# Total from tracts: 91,026
# Total from neighborhoods: 77,566
# Difference: -14.79%
#
# total_under5_avg:
# Total from tracts: 59,192
# Total from neighborhoods: 49,536
# Difference: -16.31%
#
# total_5to9_avg:
# Total from tracts: 58,779
# Total from neighborhoods: 49,251
# Difference: -16.21%
#
# total10to14_avg:
# Total from tracts: 61,812
# Total from neighborhoods: 52,565
# Difference: -14.96%
#
# total_15to19_avg:
# Total from tracts: 61,256
# Total from neighborhoods: 52,834
# Difference: -13.75%
#
# total_20to24_avg:
# Total from tracts: 68,558
# Total from neighborhoods: 60,860
# Difference: -11.23%
#
# total_25to29_avg:
# Total from tracts: 80,737
# Total from neighborhoods: 67,821
# Difference: -16.00%
#
# total_30to34_avg:
# Total from tracts: 73,366
# Total from neighborhoods: 57,681
# Difference: -21.38%
#
# total_35to39_avg:
# Total from tracts: 61,068
# Total from neighborhoods: 48,030
# Difference: -21.35%
#
# total_40to44_avg:
# Total from tracts: 54,794
# Total from neighborhoods: 44,166
# Difference: -19.40%
#
# total_45to49_avg:
# Total from tracts: 47,380
# Total from neighborhoods: 37,235
# Difference: -21.41%
#
# total_50to54_avg:
# Total from tracts: 47,704
# Total from neighborhoods: 37,606
# Difference: -21.17%
#
# total_55to59_avg:
# Total from tracts: 49,522
# Total from neighborhoods: 38,824
# Difference: -21.60%
#
# total_60to64_avg:
# Total from tracts: 46,800
# Total from neighborhoods: 35,509
# Difference: -24.12%
#
# total_65to69_avg:
# Total from tracts: 40,902
# Total from neighborhoods: 29,354
# Difference: -28.23%
#
# total_70to74_avg:
# Total from tracts: 29,619
# Total from neighborhoods: 21,066
# Difference: -28.88%
#
# total_75to79_avg:
# Total from tracts: 17,264
# Total from neighborhoods: 12,979
# Difference: -24.82%
#
# total_80to84_avg:
# Total from tracts: 11,096
# Total from neighborhoods: 7,915
# Difference: -28.68%
#
# total_85andolder_avg:
# Total from tracts: 14,412
# Total from neighborhoods: 9,782
# Difference: -32.13%
#
# total_under18_avg:
# Total from tracts: 212,761
# Total from neighborhoods: 179,144
# Difference: -15.80%
#
# total_16andover_avg:
# Total from tracts: 693,311
# Total from neighborhoods: 552,142
# Difference: -20.36%
#
# total_over18_avg:
# Total from tracts: 671,498
# Total from neighborhoods: 533,871
# Difference: -20.50%
#
# totalmale_avg:
# Total from tracts: 431,172
# Total from neighborhoods: 348,313
# Difference: -19.22%
#
# male_under5_avg:
# Total from tracts: 30,656
# Total from neighborhoods: 25,750
# Difference: -16.00%
#
# male_5to9_avg:
# Total from tracts: 29,916
# Total from neighborhoods: 24,929
# Difference: -16.67%
#
# male_10to14_avg:
# Total from tracts: 31,541
# Total from neighborhoods: 26,986
# Difference: -14.44%
#
# male_15to19_avg:
# Total from tracts: 30,761
# Total from neighborhoods: 26,582
# Difference: -13.59%
#
# male_20to24_avg:
# Total from tracts: 33,616
# Total from neighborhoods: 30,163
# Difference: -10.27%
#
# male_25to29_avg:
# Total from tracts: 40,055
# Total from neighborhoods: 33,440
# Difference: -16.51%
#
# male_30to34_avg:
# Total from tracts: 35,842
# Total from neighborhoods: 28,429
# Difference: -20.68%
#
# male_35to39_avg:
# Total from tracts: 30,310
# Total from neighborhoods: 23,296
# Difference: -23.14%
#
# male_40to44_avg:
# Total from tracts: 26,446
# Total from neighborhoods: 20,805
# Difference: -21.33%
#
# male_45to49_avg:
# Total from tracts: 23,231
# Total from neighborhoods: 17,979
# Difference: -22.61%
#
# male_50to54_avg:
# Total from tracts: 23,178
# Total from neighborhoods: 18,111
# Difference: -21.86%
#
# male_55to59_avg:
# Total from tracts: 23,355
# Total from neighborhoods: 18,274
# Difference: -21.76%
#
# male_60to64_avg:
# Total from tracts: 23,115
# Total from neighborhoods: 17,597
# Difference: -23.87%
#
# male_65to69_avg:
# Total from tracts: 18,652
# Total from neighborhoods: 13,321
# Difference: -28.58%
#
# male_70to74_avg:
# Total from tracts: 13,922
# Total from neighborhoods: 10,282
# Difference: -26.14%
#
# male_75to79_avg:
# Total from tracts: 7,973
# Total from neighborhoods: 6,171
# Difference: -22.60%
#
# male_80to84_avg:
# Total from tracts: 4,502
# Total from neighborhoods: 3,319
# Difference: -26.27%
#
# male_85andover_avg:
# Total from tracts: 4,102
# Total from neighborhoods: 2,877
# Difference: -29.86%
#
# male_under18_avg:
# Total from tracts: 108,619
# Total from neighborhoods: 91,843
# Difference: -15.44%
#
# male_16andover_avg:
# Total from tracts: 333,696
# Total from neighborhoods: 265,886
# Difference: -20.32%
#
# male_over18_avg:
# Total from tracts: 322,552
# Total from neighborhoods: 256,470
# Difference: -20.49%
#
# totalfemale_avg:
# Total from tracts: 453,088
# Total from neighborhoods: 364,701
# Difference: -19.51%
#
# female_under5_avg:
# Total from tracts: 28,536
# Total from neighborhoods: 23,786
# Difference: -16.65%
#
# female_5to9_avg:
# Total from tracts: 28,863
# Total from neighborhoods: 24,322
# Difference: -15.73%
#
# female_10to14_avg:
# Total from tracts: 30,270
# Total from neighborhoods: 25,579
# Difference: -15.50%
#
# female_15to19_avg:
# Total from tracts: 30,495
# Total from neighborhoods: 26,252
# Difference: -13.91%
#
# female_20to24_avg:
# Total from tracts: 34,942
# Total from neighborhoods: 30,697
# Difference: -12.15%
#
# female_25to29_avg:
# Total from tracts: 40,682
# Total from neighborhoods: 34,381
# Difference: -15.49%
#
# female_30to34_avg:
# Total from tracts: 37,524
# Total from neighborhoods: 29,252
# Difference: -22.04%
#
# female_35to39_avg:
# Total from tracts: 30,758
# Total from neighborhoods: 24,734
# Difference: -19.58%
#
# female_40to44_avg:
# Total from tracts: 28,349
# Total from neighborhoods: 23,360
# Difference: -17.60%
#
# female_45to49_avg:
# Total from tracts: 24,148
# Total from neighborhoods: 19,256
# Difference: -20.26%
#
# female_50to54_avg:
# Total from tracts: 24,526
# Total from neighborhoods: 19,495
# Difference: -20.51%
#
# female_55to59_avg:
# Total from tracts: 26,166
# Total from neighborhoods: 20,550
# Difference: -21.47%
#
# female_60to64_avg:
# Total from tracts: 23,684
# Total from neighborhoods: 17,913
# Difference: -24.37%
#
# female_65to69_avg:
# Total from tracts: 22,249
# Total from neighborhoods: 16,033
# Difference: -27.94%
#
# female_70to74_avg:
# Total from tracts: 15,698
# Total from neighborhoods: 10,783
# Difference: -31.30%
#
# female_75to79_avg:
# Total from tracts: 9,291
# Total from neighborhoods: 6,808
# Difference: -26.72%
#
# female_80to84_avg:
# Total from tracts: 6,594
# Total from neighborhoods: 4,595
# Difference: -30.32%
#
# female_85andover_avg:
# Total from tracts: 10,310
# Total from neighborhoods: 6,904
# Difference: -33.04%
#
# female_under18_avg:
# Total from tracts: 104,142
# Total from neighborhoods: 87,300
# Difference: -16.17%
#
# female_16andover_avg:
# Total from tracts: 359,616
# Total from neighborhoods: 286,256
# Difference: -20.40%
#
# female_over18_avg:
# Total from tracts: 348,946
# Total from neighborhoods: 277,401
# Difference: -20.50%
#
# total_nothispanic_avg:
# Total from tracts: 724,560
# Total from neighborhoods: 573,139
# Difference: -20.90%
#
# white_not_hisp_avg:
# Total from tracts: 345,349
# Total from neighborhoods: 227,202
# Difference: -34.21%
#
# black_not_hisp_avg:
# Total from tracts: 301,595
# Total from neighborhoods: 285,561
# Difference: -5.32%
#
# ai_an_not_hisp_avg:
# Total from tracts: 3,336
# Total from neighborhoods: 2,656
# Difference: -20.39%
#
# asian_not_hisp_avg:
# Total from tracts: 39,443
# Total from neighborhoods: 31,002
# Difference: -21.40%
#
# nh_opi_not_hisp_avg:
# Total from tracts: 102
# Total from neighborhoods: 71
# Difference: -30.33%
#
# otherrace_not_hisp_avg:
# Total from tracts: 3,138
# Total from neighborhoods: 1,871
# Difference: -40.38%
#
# two_or_more_race_not_hisp_avg:
# Total from tracts: 31,596
# Total from neighborhoods: 24,777
# Difference: -21.58%
#
# total_hispanic_avg:
# Total from tracts: 159,700
# Total from neighborhoods: 139,875
# Difference: -12.41%
#
# hispanic_white_avg:
# Total from tracts: 39,514
# Total from neighborhoods: 33,708
# Difference: -14.69%
#
# hispanic_black_avg:
# Total from tracts: 5,060
# Total from neighborhoods: 4,595
# Difference: -9.19%
#
# hispanic_ai_an_avg:
# Total from tracts: 2,064
# Total from neighborhoods: 1,832
# Difference: -11.20%
#
# hispanic_asian_avg:
# Total from tracts: 314
# Total from neighborhoods: 291
# Difference: -7.44%
#
# hispanic_nh_opi_avg:
# Total from tracts: 39
# Total from neighborhoods: 39
# Difference: -0.00%
#
# hispanic_otherrace_avg:
# Total from tracts: 53,280
# Total from neighborhoods: 46,621
# Difference: -12.50%
#
# hispanic_two_or_more_race_avg:
# Total from tracts: 59,429
# Total from neighborhoods: 52,789
# Difference: -11.17%
#
# Labor Force Participation Rate:
# Average from tracts: 63.36%
# Average from neighborhoods: 63.91%
# Difference: 0.86%
#
# Employment/Population Ratio:
# Average from tracts: 59.33%
# Average from neighborhoods: 60.31%
# Difference: 1.66%
#
# Unemployment rate:
# Average from tracts: 6.52%
# Average from neighborhoods: 5.74%
# Difference: -12.02%

# %%
# # Define the demographic columns you want to estimate for neighborhoods
# demographic_cols = ['Population', 'totalpop_avg', 'white_avg', 'black_avg', 'asian_avg', 'ai_an_avg', 'nh_opi_avg', 'otherrace_avg', 
#     'two_or_more_race_avg', 'total_under5_avg', 'total_5to9_avg', 'total10to14_avg', 
#     'total_15to19_avg', 'total_20to24_avg', 'total_25to29_avg', 'total_30to34_avg', 
#     'total_35to39_avg', 'total_40to44_avg', 'total_45to49_avg', 'total_50to54_avg', 
#     'total_55to59_avg', 'total_60to64_avg', 'total_65to69_avg', 'total_70to74_avg', 
#     'total_75to79_avg', 'total_80to84_avg', 'total_85andolder_avg', 'total_under18_avg', 
#     'total_16andover_avg', 'total_over18_avg', 'totalmale_avg', 'male_under5_avg', 
#     'male_5to9_avg', 'male_10to14_avg', 'male_15to19_avg', 'male_20to24_avg', 'male_25to29_avg',
#     'male_30to34_avg', 'male_35to39_avg', 'male_40to44_avg', 'male_45to49_avg', 'male_50to54_avg',
#     'male_55to59_avg', 'male_60to64_avg', 'male_65to69_avg', 'male_70to74_avg', 'male_75to79_avg',
#     'male_80to84_avg', 'male_85andover_avg', 'male_under18_avg', 'male_16andover_avg', 'male_over18_avg',
#     'totalfemale_avg', 'female_under5_avg', 'female_5to9_avg', 'female_10to14_avg', 'female_15to19_avg',
#     'female_20to24_avg', 'female_25to29_avg', 'female_30to34_avg', 'female_35to39_avg', 'female_40to44_avg',
#     'female_45to49_avg', 'female_50to54_avg', 'female_55to59_avg', 'female_60to64_avg', 'female_65to69_avg',
#     'female_70to74_avg', 'female_75to79_avg', 'female_80to84_avg', 'female_85andover_avg', 'female_under18_avg',
#     'female_16andover_avg', 'female_over18_avg', 'total_nothispanic_avg', 'white_not_hisp_avg', 'black_not_hisp_avg',
#     'ai_an_not_hisp_avg', 'asian_not_hisp_avg', 'nh_opi_not_hisp_avg', 'otherrace_not_hisp_avg', 'two_or_more_race_not_hisp_avg',
#     'total_hispanic_avg', 'hispanic_white_avg', 'hispanic_black_avg', 'hispanic_ai_an_avg', 'hispanic_asian_avg',
#     'hispanic_nh_opi_avg', 'hispanic_otherrace_avg', 'hispanic_two_or_more_race_avg']


# def estimate_neighborhood_demographics(tract_df, neighborhood_df, demographic_columns):
#     """
#     Estimate neighborhood demographics based on overlapping census tracts.
#     """
#     # Create copies to avoid modifying original data
#     tracts = tract_df.copy()
#     neighborhoods = neighborhood_df.copy()
    
#     # Calculate tract areas for later proportion calculations
#     tracts['tract_area'] = tracts.geometry.area
    
#     # Perform spatial intersection
#     intersections = gpd.overlay(tracts, neighborhoods, how='intersection')
    
#     # Calculate the area of each intersection
#     intersections['overlap_area'] = intersections.geometry.area
    
#     # Calculate what proportion of each tract falls in each neighborhood
#     intersections['tract_proportion'] = intersections['overlap_area'] / intersections['tract_area']
    
#     # Initialize a dictionary to store results
#     demographic_estimates = {}
    
#     # Calculate weighted demographics for each neighborhood
#     for col in demographic_columns:
#         # Multiply demographic values by the proportion of tract area
#         intersections[f'{col}_weighted'] = intersections[col] * intersections['tract_proportion']
        
#         # Sum up the weighted values for each neighborhood
#         demographic_estimates[col] = intersections.groupby('Neighborho')[f'{col}_weighted'].sum()
    
#     # Create results DataFrame
#     results = pd.DataFrame(demographic_estimates)
    
#     # Merge results back with original neighborhood data
#     final_results = neighborhoods.merge(results, left_on='Neighborho', right_index=True)
    
#     return final_results

# # Calculate the estimates
# try:
#     neighborhood_estimates = estimate_neighborhood_demographics(
#         map_acs5yr,  # your census tract data
#         neighborhood_gdf,  # your neighborhood data
#         demographic_cols
#     )
    
#     # Print summary of results
#     print("\nNeighborhood Demographic Estimates:")
#     print("-" * 50)
#     for idx, row in neighborhood_estimates.iterrows():
#         print(f"\nNeighborhood: {row['Neighborho']}")
#         for col in demographic_cols[:5]:  # Print first 5 demographic columns as example
#             print(f"{col}: {row[col]:,.2f}")
            
#     # Basic verification
#     print("\nVerification of total population:")
#     print(f"Sum of tract populations: {map_acs5yr['totalpop_avg'].sum():,.2f}")
#     print(f"Sum of estimated neighborhood populations: {neighborhood_estimates['totalpop_avg'].sum():,.2f}")
    
# except Exception as e:
#     print(f"An error occurred: {str(e)}")
#     print("\nAvailable columns in tract data:")
#     print(map_acs5yr.columns)
#     print("\nAvailable columns in neighborhood data:")
#     print(neighborhood_gdf.columns)
# Out:
# Neighborhood Demographic Estimates:
# --------------------------------------------------
#
# Neighborhood: NEW COELN
# Population: 213.06
# totalpop_avg: 256.88
# white_avg: 206.05
# black_avg: 2.01
# asian_avg: 10.51
#
# Neighborhood: SOUTHPOINT
# Population: 2,335.45
# totalpop_avg: 3,277.21
# white_avg: 1,719.46
# black_avg: 168.00
# asian_avg: 340.44
#
# Neighborhood: TOWN OF LAKE
# Population: 3,649.39
# totalpop_avg: 4,565.12
# white_avg: 3,526.61
# black_avg: 218.54
# asian_avg: 128.48
#
# Neighborhood: TIPPECANOE
# Population: 4,799.79
# totalpop_avg: 5,783.84
# white_avg: 4,859.68
# black_avg: 226.08
# asian_avg: 26.16
#
# Neighborhood: MORGANDALE
# Population: 7,474.98
# totalpop_avg: 10,195.09
# white_avg: 4,560.56
# black_avg: 540.65
# asian_avg: 748.04
#
# Neighborhood: SOUTHGATE
# Population: 3,646.93
# totalpop_avg: 4,941.15
# white_avg: 2,250.55
# black_avg: 346.18
# asian_avg: 404.83
#
# Neighborhood: BAY VIEW
# Population: 15,051.40
# totalpop_avg: 17,802.06
# white_avg: 14,183.48
# black_avg: 671.11
# asian_avg: 251.95
#
# Neighborhood: WEDGEWOOD
# Population: 1,611.76
# totalpop_avg: 2,098.24
# white_avg: 1,503.13
# black_avg: 47.03
# asian_avg: 120.31
#
# Neighborhood: FAIRVIEW
# Population: 2,956.79
# totalpop_avg: 3,913.95
# white_avg: 2,503.81
# black_avg: 98.41
# asian_avg: 217.81
#
# Neighborhood: MENOMONEE RIVER VALLEY
# Population: 5,451.06
# totalpop_avg: 6,093.23
# white_avg: 3,590.51
# black_avg: 1,167.34
# asian_avg: 228.95
#
# Neighborhood: MARQUETTE
# Population: 1,430.36
# totalpop_avg: 1,481.67
# white_avg: 1,098.86
# black_avg: 178.76
# asian_avg: 108.43
#
# Neighborhood: MARTIN DRIVE
# Population: 736.43
# totalpop_avg: 870.59
# white_avg: 387.27
# black_avg: 365.03
# asian_avg: 22.23
#
# Neighborhood: FAIR PARK
# Population: 1,586.49
# totalpop_avg: 1,965.62
# white_avg: 1,502.02
# black_avg: 118.67
# asian_avg: 60.61
#
# Neighborhood: ZOO
# Population: 1,098.11
# totalpop_avg: 1,218.21
# white_avg: 875.11
# black_avg: 85.86
# asian_avg: 58.06
#
# Neighborhood: MIDTOWN
# Population: 4,518.57
# totalpop_avg: 6,320.79
# white_avg: 610.52
# black_avg: 4,028.34
# asian_avg: 1,077.40
#
# Neighborhood: TRIANGLE
# Population: 432.29
# totalpop_avg: 564.68
# white_avg: 36.06
# black_avg: 440.61
# asian_avg: 64.87
#
# Neighborhood: HILLSIDE
# Population: 3,366.73
# totalpop_avg: 4,857.98
# white_avg: 586.40
# black_avg: 3,701.70
# asian_avg: 56.83
#
# Neighborhood: UPTOWN
# Population: 6,702.67
# totalpop_avg: 8,940.92
# white_avg: 1,895.45
# black_avg: 5,866.29
# asian_avg: 235.02
#
# Neighborhood: HAVENWOODS
# Population: 1,912.52
# totalpop_avg: 2,601.11
# white_avg: 201.22
# black_avg: 2,024.68
# asian_avg: 239.62
#
# Neighborhood: MC GOVERN PARK
# Population: 3,631.55
# totalpop_avg: 5,240.23
# white_avg: 468.30
# black_avg: 4,229.51
# asian_avg: 90.84
#
# Neighborhood: HAMPTON HEIGHTS
# Population: 10,273.76
# totalpop_avg: 14,256.84
# white_avg: 1,523.54
# black_avg: 10,581.26
# asian_avg: 662.67
#
# Neighborhood: NORTHPOINT
# Population: 5,585.99
# totalpop_avg: 5,969.67
# white_avg: 4,921.09
# black_avg: 330.90
# asian_avg: 329.11
#
# Neighborhood: RIVERWEST
# Population: 16,810.78
# totalpop_avg: 19,231.29
# white_avg: 12,525.32
# black_avg: 3,617.86
# asian_avg: 373.24
#
# Neighborhood: HARAMBEE
# Population: 8,136.79
# totalpop_avg: 11,586.44
# white_avg: 1,369.12
# black_avg: 8,793.74
# asian_avg: 13.47
#
# Neighborhood: WILLIAMSBURG
# Population: 1,169.29
# totalpop_avg: 1,444.77
# white_avg: 183.69
# black_avg: 1,084.86
# asian_avg: 8.63
#
# Neighborhood: VALHALLA
# Population: 2,393.95
# totalpop_avg: 3,406.73
# white_avg: 285.82
# black_avg: 2,836.27
# asian_avg: 110.96
#
# Neighborhood: LAND BANK
# Population: 2,062.44
# totalpop_avg: 2,644.86
# white_avg: 570.21
# black_avg: 1,806.83
# asian_avg: 94.75
#
# Neighborhood: BRYNWOOD
# Population: 1,350.52
# totalpop_avg: 1,747.83
# white_avg: 375.21
# black_avg: 1,230.58
# asian_avg: 67.34
#
# Neighborhood: NORTH GRANVILLE
# Population: 1,875.54
# totalpop_avg: 3,160.53
# white_avg: 344.29
# black_avg: 2,159.28
# asian_avg: 489.07
#
# Neighborhood: NORTHRIDGE
# Population: 1,322.47
# totalpop_avg: 2,029.05
# white_avg: 341.74
# black_avg: 1,470.89
# asian_avg: 103.72
#
# Neighborhood: RIDGEVIEW
# Population: 482.62
# totalpop_avg: 740.47
# white_avg: 124.71
# black_avg: 536.78
# asian_avg: 37.85
#
# Neighborhood: GRACELAND
# Population: 1,971.82
# totalpop_avg: 2,665.99
# white_avg: 500.59
# black_avg: 1,880.28
# asian_avg: 134.14
#
# Neighborhood: FAIRFIELD
# Population: 2,048.70
# totalpop_avg: 2,701.55
# white_avg: 328.48
# black_avg: 2,117.68
# asian_avg: 75.55
#
# Neighborhood: POLONIA
# Population: 7,937.47
# totalpop_avg: 11,034.50
# white_avg: 3,837.65
# black_avg: 428.44
# asian_avg: 522.96
#
# Neighborhood: FERNWOOD
# Population: 2,075.95
# totalpop_avg: 2,463.92
# white_avg: 2,079.75
# black_avg: 96.07
# asian_avg: 55.35
#
# Neighborhood: CONCORDIA
# Population: 2,542.47
# totalpop_avg: 2,975.04
# white_avg: 789.93
# black_avg: 1,680.33
# asian_avg: 11.43
#
# Neighborhood: GRA-RAM
# Population: 1,462.05
# totalpop_avg: 1,911.60
# white_avg: 1,419.98
# black_avg: 22.03
# asian_avg: 32.11
#
# Neighborhood: LYONS PARK
# Population: 1,376.19
# totalpop_avg: 1,764.67
# white_avg: 969.24
# black_avg: 100.35
# asian_avg: 125.41
#
# Neighborhood: VETERANS AFFAIRS
# Population: 643.70
# totalpop_avg: 795.68
# white_avg: 300.44
# black_avg: 223.45
# asian_avg: 13.15
#
# Neighborhood: ALVERNO
# Population: 1,136.97
# totalpop_avg: 1,342.17
# white_avg: 716.13
# black_avg: 201.95
# asian_avg: 8.61
#
# Neighborhood: SILVER SPRING
# Population: 7,100.35
# totalpop_avg: 10,197.78
# white_avg: 886.30
# black_avg: 6,964.30
# asian_avg: 1,172.48
#
# Neighborhood: SILVER SWAN
# Population: 2,159.18
# totalpop_avg: 3,006.58
# white_avg: 380.69
# black_avg: 1,947.45
# asian_avg: 360.28
#
# Neighborhood: WAHL PARK
# Population: 1,869.32
# totalpop_avg: 2,770.41
# white_avg: 301.79
# black_avg: 2,195.17
# asian_avg: 126.81
#
# Neighborhood: GRANTOSA
# Population: 1,322.74
# totalpop_avg: 1,785.61
# white_avg: 414.32
# black_avg: 1,142.33
# asian_avg: 48.53
#
# Neighborhood: LINCOLN CREEK
# Population: 5,700.18
# totalpop_avg: 8,595.11
# white_avg: 547.07
# black_avg: 7,108.56
# asian_avg: 224.31
#
# Neighborhood: ST. AMELIAN'S
# Population: 1,119.24
# totalpop_avg: 1,351.41
# white_avg: 831.74
# black_avg: 378.27
# asian_avg: 17.06
#
# Neighborhood: OLD NORTH MILWAUKEE
# Population: 13,982.75
# totalpop_avg: 20,650.27
# white_avg: 1,878.99
# black_avg: 16,672.85
# asian_avg: 165.29
#
# Neighborhood: LINCOLN PARK
# Population: 12,006.07
# totalpop_avg: 15,643.44
# white_avg: 1,307.44
# black_avg: 13,524.33
# asian_avg: 54.34
#
# Neighborhood: ESTABROOK PARK
# Population: 634.37
# totalpop_avg: 794.31
# white_avg: 198.84
# black_avg: 515.20
# asian_avg: 8.05
#
# Neighborhood: RUFUS KING
# Population: 5,885.02
# totalpop_avg: 7,996.00
# white_avg: 378.41
# black_avg: 6,989.53
# asian_avg: 52.67
#
# Neighborhood: GARDEN HOMES
# Population: 2,612.80
# totalpop_avg: 4,084.95
# white_avg: 270.49
# black_avg: 3,431.77
# asian_avg: 13.62
#
# Neighborhood: ARLINGTON HEIGHTS
# Population: 2,570.75
# totalpop_avg: 3,956.89
# white_avg: 119.12
# black_avg: 3,617.75
# asian_avg: 6.80
#
# Neighborhood: BORCHERT FIELD
# Population: 1,996.79
# totalpop_avg: 2,686.34
# white_avg: 165.43
# black_avg: 2,342.36
# asian_avg: 0.36
#
# Neighborhood: FRANKLIN HEIGHTS
# Population: 6,864.94
# totalpop_avg: 9,956.95
# white_avg: 51.80
# black_avg: 9,399.83
# asian_avg: 181.70
#
# Neighborhood: ROOSEVELT GROVE
# Population: 4,922.78
# totalpop_avg: 6,602.56
# white_avg: 364.28
# black_avg: 5,944.50
# asian_avg: 133.61
#
# Neighborhood: GRASSLYN MANOR
# Population: 3,478.26
# totalpop_avg: 4,647.34
# white_avg: 740.19
# black_avg: 3,540.13
# asian_avg: 46.38
#
# Neighborhood: DINEEN PARK
# Population: 2,717.12
# totalpop_avg: 3,672.90
# white_avg: 353.65
# black_avg: 3,006.22
# asian_avg: 227.36
#
# Neighborhood: SUNSET HEIGHTS
# Population: 2,782.44
# totalpop_avg: 3,878.48
# white_avg: 588.09
# black_avg: 2,986.94
# asian_avg: 68.24
#
# Neighborhood: ENDERIS PARK
# Population: 3,249.06
# totalpop_avg: 4,244.22
# white_avg: 1,981.03
# black_avg: 1,918.70
# asian_avg: 58.80
#
# Neighborhood: SAINT JOSEPH
# Population: 6,603.98
# totalpop_avg: 8,985.66
# white_avg: 1,397.55
# black_avg: 6,425.09
# asian_avg: 161.37
#
# Neighborhood: SHERMAN PARK
# Population: 6,591.74
# totalpop_avg: 9,637.92
# white_avg: 670.34
# black_avg: 8,367.41
# asian_avg: 168.51
#
# Neighborhood: AMANI
# Population: 4,871.91
# totalpop_avg: 6,891.19
# white_avg: 272.47
# black_avg: 6,146.61
# asian_avg: 90.99
#
# Neighborhood: NORTH DIVISION
# Population: 5,546.56
# totalpop_avg: 7,636.67
# white_avg: 293.17
# black_avg: 6,903.13
# asian_avg: 74.13
#
# Neighborhood: METCALFE PARK
# Population: 3,037.23
# totalpop_avg: 5,035.07
# white_avg: 326.23
# black_avg: 4,047.86
# asian_avg: 246.31
#
# Neighborhood: DOWNER WOODS
# Population: 3,685.92
# totalpop_avg: 4,073.52
# white_avg: 3,158.42
# black_avg: 213.91
# asian_avg: 236.27
#
# Neighborhood: UPPER EAST SIDE
# Population: 3,847.76
# totalpop_avg: 4,027.36
# white_avg: 3,377.22
# black_avg: 128.15
# asian_avg: 244.45
#
# Neighborhood: MURRAY HILL
# Population: 5,498.51
# totalpop_avg: 5,847.35
# white_avg: 4,727.44
# black_avg: 399.57
# asian_avg: 326.04
#
# Neighborhood: NASH PARK
# Population: 1,783.88
# totalpop_avg: 2,178.15
# white_avg: 951.66
# black_avg: 947.41
# asian_avg: 26.00
#
# Neighborhood: KOPS PARK
# Population: 2,078.91
# totalpop_avg: 2,501.49
# white_avg: 1,344.60
# black_avg: 840.09
# asian_avg: 49.90
#
# Neighborhood: MOUNT MARY
# Population: 1,846.21
# totalpop_avg: 2,274.08
# white_avg: 1,738.93
# black_avg: 224.21
# asian_avg: 30.60
#
# Neighborhood: COOPER PARK
# Population: 2,167.65
# totalpop_avg: 2,778.21
# white_avg: 1,851.92
# black_avg: 626.18
# asian_avg: 2.34
#
# Neighborhood: WASHINGTON HEIGHTS
# Population: 5,165.61
# totalpop_avg: 6,448.75
# white_avg: 4,122.43
# black_avg: 1,592.79
# asian_avg: 91.61
#
# Neighborhood: WASHINGTON PARK
# Population: 2,347.53
# totalpop_avg: 3,471.77
# white_avg: 256.58
# black_avg: 2,867.51
# asian_avg: 245.43
#
# Neighborhood: HILLTOP PARISH
# Population: 228.54
# totalpop_avg: 350.65
# white_avg: 59.06
# black_avg: 254.19
# asian_avg: 17.92
#
# Neighborhood: WOODLANDS
# Population: 406.89
# totalpop_avg: 684.90
# white_avg: 75.07
# black_avg: 468.25
# asian_avg: 105.19
#
# Neighborhood: NORTHRIDGE LAKES
# Population: 1,032.79
# totalpop_avg: 1,582.94
# white_avg: 269.10
# black_avg: 1,144.20
# asian_avg: 81.27
#
# Neighborhood: FREEDOM VILLAGE
# Population: 141.54
# totalpop_avg: 181.66
# white_avg: 40.30
# black_avg: 121.41
# asian_avg: 6.71
#
# Neighborhood: SERVITE WOODS
# Population: 274.42
# totalpop_avg: 352.49
# white_avg: 75.66
# black_avg: 239.05
# asian_avg: 12.49
#
# Neighborhood: GRANVILLE STATION
# Population: 1,036.02
# totalpop_avg: 1,612.67
# white_avg: 355.11
# black_avg: 943.61
# asian_avg: 224.24
#
# Neighborhood: WHISPERING HILLS
# Population: 163.34
# totalpop_avg: 209.89
# white_avg: 45.03
# black_avg: 142.36
# asian_avg: 7.44
#
# Neighborhood: GRANVILLE WOODS
# Population: 225.13
# totalpop_avg: 287.60
# white_avg: 63.46
# black_avg: 192.83
# asian_avg: 10.33
#
# Neighborhood: RIVERTON HEIGHTS
# Population: 281.83
# totalpop_avg: 421.74
# white_avg: 118.13
# black_avg: 224.37
# asian_avg: 55.24
#
# Neighborhood: PHEASANT RUN
# Population: 358.96
# totalpop_avg: 537.15
# white_avg: 150.46
# black_avg: 285.77
# asian_avg: 70.36
#
# Neighborhood: BRADLEY ESTATES
# Population: 1,143.59
# totalpop_avg: 1,479.99
# white_avg: 317.68
# black_avg: 1,042.18
# asian_avg: 56.97
#
# Neighborhood: POLLBER HEIGHTS
# Population: 135.90
# totalpop_avg: 173.67
# white_avg: 37.53
# black_avg: 117.55
# asian_avg: 6.07
#
# Neighborhood: BUCHEL PARK
# Population: 15.95
# totalpop_avg: 20.38
# white_avg: 4.41
# black_avg: 13.79
# asian_avg: 0.71
#
# Neighborhood: CALUMET FARMS
# Population: 1,348.22
# totalpop_avg: 2,016.79
# white_avg: 564.67
# black_avg: 1,073.41
# asian_avg: 263.87
#
# Neighborhood: MELODY VIEW
# Population: 195.85
# totalpop_avg: 250.26
# white_avg: 54.09
# black_avg: 169.30
# asian_avg: 8.77
#
# Neighborhood: DRETZKA PARK
# Population: 828.68
# totalpop_avg: 1,396.45
# white_avg: 152.16
# black_avg: 953.94
# asian_avg: 216.18
#
# Neighborhood: PARK PLACE
# Population: 1,359.40
# totalpop_avg: 2,033.99
# white_avg: 569.78
# black_avg: 1,082.09
# asian_avg: 266.34
#
# Neighborhood: BROWN DEER PARK
# Population: 1,246.88
# totalpop_avg: 1,927.74
# white_avg: 214.80
# black_avg: 1,402.68
# asian_avg: 106.02
#
# Neighborhood: TRIPOLI PARK
# Population: 501.38
# totalpop_avg: 775.87
# white_avg: 84.43
# black_avg: 566.32
# asian_avg: 42.69
#
# Neighborhood: TOWN & COUNTRY MANOR
# Population: 1,029.09
# totalpop_avg: 1,531.57
# white_avg: 211.89
# black_avg: 1,099.00
# asian_avg: 81.37
#
# Neighborhood: WYRICK PARK
# Population: 1,107.15
# totalpop_avg: 1,522.48
# white_avg: 302.51
# black_avg: 1,057.03
# asian_avg: 74.65
#
# Neighborhood: MENOMONEE RIVER HILLS EAST
# Population: 3,844.97
# totalpop_avg: 5,323.56
# white_avg: 1,214.98
# black_avg: 2,787.79
# asian_avg: 573.00
#
# Neighborhood: THURSTON WOODS
# Population: 2,241.85
# totalpop_avg: 2,992.34
# white_avg: 341.61
# black_avg: 2,444.13
# asian_avg: 7.58
#
# Neighborhood: MENOMONEE RIVER HILLS
# Population: 5,271.31
# totalpop_avg: 7,086.99
# white_avg: 1,398.79
# black_avg: 4,089.59
# asian_avg: 1,110.40
#
# Neighborhood: GOLDEN GATE
# Population: 580.91
# totalpop_avg: 724.07
# white_avg: 174.14
# black_avg: 388.38
# asian_avg: 115.20
#
# Neighborhood: PARKWAY HILLS
# Population: 1,199.02
# totalpop_avg: 1,745.37
# white_avg: 226.58
# black_avg: 1,275.62
# asian_avg: 104.49
#
# Neighborhood: MAPLE TREE
# Population: 749.18
# totalpop_avg: 1,118.88
# white_avg: 82.64
# black_avg: 915.34
# asian_avg: 28.48
#
# Neighborhood: LITTLE MENOMONEE PARKWAY
# Population: 1,299.77
# totalpop_avg: 1,806.14
# white_avg: 564.26
# black_avg: 959.51
# asian_avg: 94.86
#
# Neighborhood: MACK ACRES
# Population: 376.28
# totalpop_avg: 469.90
# white_avg: 112.09
# black_avg: 253.60
# asian_avg: 74.03
#
# Neighborhood: HERITAGE HEIGHTS
# Population: 1,139.70
# totalpop_avg: 1,708.69
# white_avg: 120.53
# black_avg: 1,407.36
# asian_avg: 39.07
#
# Neighborhood: MILL VALLEY
# Population: 694.74
# totalpop_avg: 847.27
# white_avg: 627.78
# black_avg: 87.12
# asian_avg: 85.77
#
# Neighborhood: PARK KNOLL
# Population: 892.52
# totalpop_avg: 1,169.29
# white_avg: 571.21
# black_avg: 376.97
# asian_avg: 66.31
#
# Neighborhood: FLORIST HIGHLANDS
# Population: 1,010.88
# totalpop_avg: 1,389.10
# white_avg: 480.09
# black_avg: 635.29
# asian_avg: 54.99
#
# Neighborhood: TIMMERMAN WEST
# Population: 4,254.02
# totalpop_avg: 5,633.43
# white_avg: 1,592.65
# black_avg: 3,036.91
# asian_avg: 177.02
#
# Neighborhood: TIMMERMAN AIRPORT
# Population: 2,479.34
# totalpop_avg: 3,467.11
# white_avg: 939.29
# black_avg: 1,800.33
# asian_avg: 70.68
#
# Neighborhood: VOGEL PARK
# Population: 3,387.91
# totalpop_avg: 4,380.22
# white_avg: 867.75
# black_avg: 3,103.07
# asian_avg: 196.94
#
# Neighborhood: LINDSAY PARK
# Population: 3,236.60
# totalpop_avg: 4,314.17
# white_avg: 767.30
# black_avg: 2,984.21
# asian_avg: 287.35
#
# Neighborhood: LONG VIEW
# Population: 5,404.75
# totalpop_avg: 7,439.70
# white_avg: 1,243.48
# black_avg: 5,456.02
# asian_avg: 417.95
#
# Neighborhood: COLUMBUS PARK
# Population: 3,093.93
# totalpop_avg: 3,886.60
# white_avg: 590.86
# black_avg: 2,611.68
# asian_avg: 487.77
#
# Neighborhood: ARLINGTON GARDENS
# Population: 2,060.62
# totalpop_avg: 2,759.79
# white_avg: 536.31
# black_avg: 1,866.82
# asian_avg: 145.11
#
# Neighborhood: CAPITOL HEIGHTS
# Population: 4,407.61
# totalpop_avg: 5,732.78
# white_avg: 583.60
# black_avg: 4,509.36
# asian_avg: 397.63
#
# Neighborhood: MILWAUKEE RIVER PARKWAY
# Population: 1,047.58
# totalpop_avg: 1,403.36
# white_avg: 328.02
# black_avg: 882.99
# asian_avg: 0.96
#
# Neighborhood: GROVER HEIGHTS
# Population: 751.45
# totalpop_avg: 1,018.68
# white_avg: 55.59
# black_avg: 882.16
# asian_avg: 7.26
#
# Neighborhood: CAMBRIDGE HEIGHTS
# Population: 2,738.85
# totalpop_avg: 3,009.19
# white_avg: 2,358.12
# black_avg: 110.06
# asian_avg: 176.25
#
# Neighborhood: RIVERSIDE PARK
# Population: 5,908.29
# totalpop_avg: 6,151.70
# white_avg: 4,929.82
# black_avg: 432.69
# asian_avg: 334.47
#
# Neighborhood: LENOX HEIGHTS
# Population: 1,677.74
# totalpop_avg: 2,185.32
# white_avg: 746.98
# black_avg: 1,199.01
# asian_avg: 39.57
#
# Neighborhood: GOLDEN VALLEY
# Population: 2,171.95
# totalpop_avg: 2,642.66
# white_avg: 1,703.34
# black_avg: 491.90
# asian_avg: 96.14
#
# Neighborhood: WALNUT HILL
# Population: 1,192.28
# totalpop_avg: 1,919.28
# white_avg: 107.27
# black_avg: 845.18
# asian_avg: 825.29
#
# Neighborhood: HAWTHORNE GLEN
# Population: 415.59
# totalpop_avg: 496.72
# white_avg: 326.22
# black_avg: 85.72
# asian_avg: 11.60
#
# Neighborhood: VALLEY FORGE
# Population: 80.03
# totalpop_avg: 94.83
# white_avg: 72.73
# black_avg: 7.79
# asian_avg: 3.66
#
# Neighborhood: MILLER VALLEY
# Population: 934.68
# totalpop_avg: 1,096.89
# white_avg: 428.50
# black_avg: 538.48
# asian_avg: 27.48
#
# Neighborhood: AVENUES WEST
# Population: 7,522.57
# totalpop_avg: 8,070.93
# white_avg: 3,941.17
# black_avg: 2,634.58
# asian_avg: 506.37
#
# Neighborhood: WICK FIELD
# Population: 1,024.95
# totalpop_avg: 1,225.01
# white_avg: 803.16
# black_avg: 212.52
# asian_avg: 27.93
#
# Neighborhood: COLD SPRING PARK
# Population: 1,213.85
# totalpop_avg: 1,679.44
# white_avg: 336.07
# black_avg: 756.49
# asian_avg: 414.76
#
# Neighborhood: TRIANGLE NORTH
# Population: 1,736.84
# totalpop_avg: 2,365.15
# white_avg: 133.02
# black_avg: 2,010.87
# asian_avg: 85.24
#
# Neighborhood: HALYARD PARK
# Population: 1,436.01
# totalpop_avg: 1,975.54
# white_avg: 310.12
# black_avg: 1,455.28
# asian_avg: 7.37
#
# Neighborhood: BREWER'S HILL
# Population: 2,325.88
# totalpop_avg: 2,819.99
# white_avg: 1,607.41
# black_avg: 961.54
# asian_avg: 64.11
#
# Neighborhood: SCHLITZ PARK
# Population: 1,025.51
# totalpop_avg: 1,201.93
# white_avg: 807.84
# black_avg: 322.29
# asian_avg: 43.21
#
# Neighborhood: HAYMARKET
# Population: 1,191.72
# totalpop_avg: 1,756.58
# white_avg: 263.41
# black_avg: 1,261.07
# asian_avg: 25.26
#
# Neighborhood: PARK VIEW
# Population: 239.08
# totalpop_avg: 323.54
# white_avg: 22.67
# black_avg: 261.61
# asian_avg: 16.33
#
# Neighborhood: KING PARK
# Population: 2,269.75
# totalpop_avg: 2,708.46
# white_avg: 976.80
# black_avg: 1,334.08
# asian_avg: 175.93
#
# Neighborhood: KILBOURN TOWN
# Population: 13,633.08
# totalpop_avg: 14,353.53
# white_avg: 7,388.66
# black_avg: 5,131.96
# asian_avg: 285.96
#
# Neighborhood: LOWER EAST SIDE
# Population: 15,285.97
# totalpop_avg: 15,604.14
# white_avg: 11,715.70
# black_avg: 1,477.50
# asian_avg: 672.54
#
# Neighborhood: YANKEE HILL
# Population: 2,835.71
# totalpop_avg: 2,858.89
# white_avg: 2,210.39
# black_avg: 241.12
# asian_avg: 155.61
#
# Neighborhood: JUNEAU TOWN
# Population: 9,020.25
# totalpop_avg: 9,100.07
# white_avg: 7,002.11
# black_avg: 632.31
# asian_avg: 747.35
#
# Neighborhood: LAKE PARK
# Population: 0.23
# totalpop_avg: 0.22
# white_avg: 0.20
# black_avg: 0.01
# asian_avg: 0.01
#
# Neighborhood: HISTORIC THIRD WARD
# Population: 3,801.91
# totalpop_avg: 3,785.91
# white_avg: 3,335.46
# black_avg: 130.07
# asian_avg: 155.66
#
# Neighborhood: WALKER'S POINT
# Population: 7,763.78
# totalpop_avg: 9,831.27
# white_avg: 3,686.85
# black_avg: 1,038.20
# asian_avg: 66.23
#
# Neighborhood: HARBOR VIEW
# Population: 3,743.74
# totalpop_avg: 4,481.29
# white_avg: 1,944.85
# black_avg: 618.27
# asian_avg: 47.99
#
# Neighborhood: JONES' ISLAND
# Population: 1,523.03
# totalpop_avg: 1,758.93
# white_avg: 1,406.16
# black_avg: 25.53
# asian_avg: 47.06
#
# Neighborhood: MITCHELL PARK
# Population: 307.23
# totalpop_avg: 380.42
# white_avg: 142.26
# black_avg: 106.08
# asian_avg: 6.52
#
# Neighborhood: CLARKE SQUARE
# Population: 4,959.48
# totalpop_avg: 6,843.34
# white_avg: 2,122.61
# black_avg: 701.80
# asian_avg: 326.69
#
# Neighborhood: NATIONAL PARK
# Population: 1,739.63
# totalpop_avg: 2,461.31
# white_avg: 925.98
# black_avg: 176.38
# asian_avg: 195.64
#
# Neighborhood: SILVER CITY
# Population: 3,105.43
# totalpop_avg: 4,239.85
# white_avg: 1,051.24
# black_avg: 713.59
# asian_avg: 210.14
#
# Neighborhood: JOHNSON'S WOODS
# Population: 1,963.57
# totalpop_avg: 2,721.16
# white_avg: 1,866.67
# black_avg: 303.39
# asian_avg: 65.64
#
# Neighborhood: BLUEMOUND HEIGHTS
# Population: 2,467.12
# totalpop_avg: 3,196.07
# white_avg: 2,494.70
# black_avg: 259.32
# asian_avg: 24.60
#
# Neighborhood: MERRILL PARK
# Population: 2,044.70
# totalpop_avg: 2,730.55
# white_avg: 486.96
# black_avg: 1,362.10
# asian_avg: 210.04
#
# Neighborhood: STORY HILL
# Population: 1,476.53
# totalpop_avg: 1,762.43
# white_avg: 1,261.92
# black_avg: 190.17
# asian_avg: 60.99
#
# Neighborhood: THE VALLEY / PIGSVILLE
# Population: 382.63
# totalpop_avg: 420.60
# white_avg: 254.97
# black_avg: 95.85
# asian_avg: 14.68
#
# Neighborhood: HONEY CREEK PARKWAY
# Population: 747.12
# totalpop_avg: 820.13
# white_avg: 682.10
# black_avg: 14.72
# asian_avg: 25.48
#
# Neighborhood: CANNON PARK
# Population: 1,216.89
# totalpop_avg: 1,350.78
# white_avg: 971.86
# black_avg: 94.63
# asian_avg: 64.31
#
# Neighborhood: BURNHAM PARK
# Population: 6,476.21
# totalpop_avg: 8,691.39
# white_avg: 3,058.77
# black_avg: 439.44
# asian_avg: 142.87
#
# Neighborhood: MUSKEGO WAY
# Population: 7,830.43
# totalpop_avg: 11,163.95
# white_avg: 3,725.70
# black_avg: 1,201.14
# asian_avg: 134.64
#
# Neighborhood: HISTORIC MITCHELL STREET
# Population: 6,598.48
# totalpop_avg: 9,451.95
# white_avg: 2,890.58
# black_avg: 977.39
# asian_avg: 402.24
#
# Neighborhood: CLOCK TOWER ACRES
# Population: 1,053.14
# totalpop_avg: 1,591.62
# white_avg: 481.94
# black_avg: 301.92
# asian_avg: 2.08
#
# Neighborhood: BARAN PARK
# Population: 1,260.97
# totalpop_avg: 1,430.08
# white_avg: 757.45
# black_avg: 170.02
# asian_avg: 39.46
#
# Neighborhood: LINCOLN VILLAGE
# Population: 9,975.12
# totalpop_avg: 13,841.59
# white_avg: 3,994.31
# black_avg: 687.20
# asian_avg: 533.08
#
# Neighborhood: FOREST HOME HILLS
# Population: 4,532.60
# totalpop_avg: 6,085.25
# white_avg: 1,923.97
# black_avg: 405.80
# asian_avg: 284.56
#
# Neighborhood: LAYTON PARK
# Population: 7,972.09
# totalpop_avg: 11,480.23
# white_avg: 3,639.40
# black_avg: 356.99
# asian_avg: 677.70
#
# Neighborhood: JACKSON PARK
# Population: 9,152.37
# totalpop_avg: 11,345.54
# white_avg: 5,666.33
# black_avg: 800.17
# asian_avg: 787.17
#
# Neighborhood: WHITE MANOR
# Population: 1,174.98
# totalpop_avg: 1,446.70
# white_avg: 975.23
# black_avg: 69.46
# asian_avg: 41.89
#
# Neighborhood: WEST VIEW
# Population: 1,543.61
# totalpop_avg: 1,791.72
# white_avg: 1,318.49
# black_avg: 77.66
# asian_avg: 64.32
#
# Neighborhood: EUCLID PARK
# Population: 1,561.22
# totalpop_avg: 1,812.28
# white_avg: 1,333.16
# black_avg: 78.35
# asian_avg: 64.88
#
# Neighborhood: HIGHWOOD ESTATES
# Population: 1,628.23
# totalpop_avg: 1,915.69
# white_avg: 1,330.75
# black_avg: 46.09
# asian_avg: 34.72
#
# Neighborhood: RIVER BEND
# Population: 1,638.54
# totalpop_avg: 1,928.68
# white_avg: 1,338.26
# black_avg: 46.74
# asian_avg: 35.52
#
# Neighborhood: HAWLEY FARMS
# Population: 1,426.99
# totalpop_avg: 1,830.46
# white_avg: 1,004.63
# black_avg: 103.60
# asian_avg: 130.58
#
# Neighborhood: ROOT CREEK
# Population: 1,684.85
# totalpop_avg: 2,160.92
# white_avg: 1,187.16
# black_avg: 122.47
# asian_avg: 154.26
#
# Neighborhood: ALCOTT PARK
# Population: 1,364.53
# totalpop_avg: 1,682.11
# white_avg: 1,275.69
# black_avg: 21.80
# asian_avg: 0.03
#
# Neighborhood: MORGAN HEIGHTS
# Population: 1,360.82
# totalpop_avg: 1,678.15
# white_avg: 1,272.19
# black_avg: 21.84
# asian_avg: 0.72
#
# Neighborhood: WOODLAND COURT
# Population: 574.61
# totalpop_avg: 747.81
# white_avg: 536.43
# black_avg: 16.62
# asian_avg: 42.78
#
# Neighborhood: GREEN MOOR
# Population: 797.92
# totalpop_avg: 997.16
# white_avg: 649.00
# black_avg: 73.29
# asian_avg: 82.40
#
# Neighborhood: HONEY CREEK MANOR
# Population: 1,899.14
# totalpop_avg: 2,372.72
# white_avg: 1,545.11
# black_avg: 174.34
# asian_avg: 194.96
#
# Neighborhood: ROLLING GREEN
# Population: 1,599.19
# totalpop_avg: 2,081.99
# white_avg: 1,493.25
# black_avg: 46.31
# asian_avg: 119.23
#
# Neighborhood: RED OAK HEIGHTS
# Population: 839.37
# totalpop_avg: 1,092.58
# white_avg: 782.47
# black_avg: 24.48
# asian_avg: 62.61
#
# Neighborhood: HARDER'S OAKS
# Population: 329.55
# totalpop_avg: 389.59
# white_avg: 207.50
# black_avg: 58.45
# asian_avg: 2.87
#
# Neighborhood: MOUNT OLIVET
# Population: 780.71
# totalpop_avg: 936.82
# white_avg: 498.51
# black_avg: 133.47
# asian_avg: 18.42
#
# Neighborhood: WILSON PARK
# Population: 3,416.78
# totalpop_avg: 4,264.10
# white_avg: 2,288.77
# black_avg: 477.92
# asian_avg: 310.63
#
# Neighborhood: SAVELAND PARK
# Population: 1,082.13
# totalpop_avg: 1,508.23
# white_avg: 1,186.27
# black_avg: 1.15
# asian_avg: 2.82
#
# Neighborhood: CASTLE MANOR
# Population: 2,304.71
# totalpop_avg: 2,937.57
# white_avg: 1,378.78
# black_avg: 236.13
# asian_avg: 453.62
#
# Neighborhood: CLAYTON CREST
# Population: 1,415.01
# totalpop_avg: 1,749.71
# white_avg: 951.57
# black_avg: 18.04
# asian_avg: 281.02
#
# Neighborhood: MITCHELL WEST
# Population: 3,131.11
# totalpop_avg: 4,163.20
# white_avg: 2,387.86
# black_avg: 220.36
# asian_avg: 560.72
#
# Neighborhood: HOLLER PARK
# Population: 625.70
# totalpop_avg: 842.60
# white_avg: 516.78
# black_avg: 18.80
# asian_avg: 130.14
#
# Neighborhood: MITCHELL FIELD
# Population: 3,547.53
# totalpop_avg: 4,280.15
# white_avg: 3,410.98
# black_avg: 50.21
# asian_avg: 175.87
#
# Neighborhood: COPERNICUS PARK
# Population: 369.43
# totalpop_avg: 445.41
# white_avg: 357.28
# black_avg: 3.49
# asian_avg: 18.23
#
# Neighborhood: GOLDMAN PARK
# Population: 371.09
# totalpop_avg: 447.41
# white_avg: 358.88
# black_avg: 3.50
# asian_avg: 18.31
#
# Neighborhood: MAITLAND PARK
# Population: 546.04
# totalpop_avg: 658.34
# white_avg: 528.07
# black_avg: 5.16
# asian_avg: 26.95
#
# Neighborhood: COLLEGE HEIGHTS
# Population: 337.69
# totalpop_avg: 407.14
# white_avg: 326.58
# black_avg: 3.19
# asian_avg: 16.66
#
# Verification of total population:
# Sum of tract populations: 884,259.50
# Sum of estimated neighborhood populations: 713,014.12

# %% [markdown]
# ### neighborhood_estimates contains demographic details by each neighborhood

# %%
# Rename the Neighborho column to Neighborhood
neighborhood_estimates = neighborhood_estimates.rename(columns = {'Neighborho' : 'Neighborhood'})

# Lower case the Neighborhood values
neighborhood_estimates['Neighborhood'] = neighborhood_estimates['Neighborhood'].fillna('').apply(str)
neighborhood_estimates['Neighborhood'] = neighborhood_estimates['Neighborhood'].str.strip().str.lower()

# Export to CSV
neighborhood_estimates.to_csv('neighborhood_estimates.csv', index = False)

# %% [markdown]
# # Bringing in the Victims and Suspects dataframes

# %%
# read the suspect and victims dataframe
df_victims = pd.read_csv("C:/Users/blah/blah/Documents/Data/Misc/dcdneighborhoods/2022-2023 - Part I Violent Crime and Part II Crime Against Person - Victim.csv")
df_suspects = pd.read_csv("C:/Users/blah/blah/Documents/Data/Misc/dcdneighborhoods/2022-2023 - Part I Violent Crime and Part II Crime Against Person - Suspect.csv")

# Cleaning the Neighborhood column for df_victims
# Replace 'nan' (string) with np.nan
df_victims['Neighborhood'] = df_victims['Neighborhood'].replace('nan', np.nan)
# Convert the 'Neighborhood' column to string values and then apply string methods
df_victims['Neighborhood'] = df_victims['Neighborhood'].fillna('').apply(str)
df_victims['Neighborhood'] = df_victims['Neighborhood'].str.strip().str.lower()

# Drop rows where 'Neighborhood' is either NaN or an empty string
df_victims = df_victims[df_victims['Neighborhood'].str.strip() != '']

# Cleaning the Neighborhood column for df_suspects
# Replace 'nan' (string) with np.nan
df_suspects['Neighborhood'] = df_suspects['Neighborhood'].replace('nan', np.nan)
# Convert the 'Neighborhood' column to string values and then apply string methods
df_suspects['Neighborhood'] = df_suspects['Neighborhood'].fillna('').apply(str)
df_suspects['Neighborhood'] = df_suspects['Neighborhood'].str.strip().str.lower()

# Drop rows where 'Neighborhood' is either NaN or an empty string
df_suspects = df_suspects[df_suspects['Neighborhood'].str.strip() != '']

# Renaming the race-ethnicity column
race_dict = {"Black / African American" : "black",
             "Hispanic / Latino" : "hispanic",
             "Native Hawaiian / Other Pacific Islander" : "NH_PI",
             "Asian" : "Asian",
             "White" : "white",
             "American Indian / Alaskan Native" : "AI_AN",
             "Unknown / Other" : "other"}

df_victims['Race-Ethnicity'] = df_victims['Race-Ethnicity'].replace(race_dict)
df_suspects['Race-Ethnicity'] = df_suspects['Race-Ethnicity'].replace(race_dict)

# Renaming the offenses
offense_dict = {"Aggravated Assault" : 'total_aggravated_assault',
                                                  "Crime Against Person" : "total_partIIperson",
                                                  'Homicide' : 'total_homicide',
                                                  'Human Trafficking' : 'total_human_trafficking',
                                                  'Rape' : 'total_rape',
                                                  'Robbery' : 'total_robbery'}

df_suspects['Offense Type'] = df_suspects['Offense Type'].replace(offense_dict)
df_victims['Offense Type'] = df_victims['Offense Type'].replace(offense_dict)

# %%
# Creating a new dataframe to count crime by neighborhood and count crime by race by neighborhood
# FOR df_victims (Offense in general)
# Pivot the table to count occurrences
pivot_vic_offtyp = df_victims.groupby(['Neighborhood', 'Offense Type']).size().unstack(fill_value = 0)
# Create a column for Race-Ethnicity and Offense Type
df_victims['Race_Offense'] = df_victims['Race-Ethnicity'] + '_' + df_victims['Offense Type']
# Create a new column counting the number of occurrence of offense type x race
df_victims['Counts'] = df_victims.groupby(['Neighborhood', 'Race_Offense']).transform('size')
pivot_vic_offrace = df_victims.pivot_table(index = 'Neighborhood', columns = 'Race_Offense', 
                                           values = 'Counts', aggfunc = 'sum',
                                           fill_value = 0)

# FOR df_victims (Part I offense)
# Create a column that crosses 'Race-Ethnicity' and 'Offense Category'
df_victims['Race_OffenseCat'] = df_victims['Race-Ethnicity'] + '_' + df_victims['Offense Category']
# Count occurence of offense category x race
df_victims['Off_Cat_Counts'] = df_victims.groupby(['Neighborhood', 'Race-Ethnicity']).transform('size')
# pivot into table
pivot_vic_offcat_race = df_victims.pivot_table(index = 'Neighborhood', columns = 'Race_OffenseCat', 
                                               values = 'Off_Cat_Counts', aggfunc = 'sum',
                                               fill_value = 0)
df_victims_new = pd.merge(pivot_vic_offcat_race, pivot_vic_offrace, left_index=True, right_index=True)
# Reset index to make 'Neighborhood' a column again
df_victims_new = df_victims_new.reset_index()

df_victims_new = pd.merge(df_victims_new, pivot_vic_offtyp, on = 'Neighborhood', how = 'outer')
# Reset index to make 'Neighborhood' a column again
df_victims_new = df_victims_new.reset_index()

# FOR df_suspects (Offense in general)
# Group by 'Neighborhood' and 'Offense Type' to count occurrences
pivot_off_type = df_suspects.groupby(['Neighborhood', 'Offense Type']).size().unstack(fill_value=0)
# Create a new column combining 'Race-Ethnicity' and 'Offense Type'
df_suspects['Race_Offense'] = df_suspects['Race-Ethnicity'] + '_' + df_suspects['Offense Type']
# Create a new column counting the number of occurrence of crime x race
df_suspects['Counts'] = df_suspects.groupby(['Neighborhood', 'Race_Offense']).transform('size')
pivot_off_race = df_suspects.pivot_table(index = 'Neighborhood', columns = 'Race_Offense', values = 'Counts', aggfunc = 'sum', fill_value = 0)

# FOR df_suspects (Part I offense)
# Create a new column combining 'Race-Ethnicity' and 'Offense Category'
df_suspects['Race_OffenseCat'] = df_suspects['Race-Ethnicity'] + '_' + df_suspects['Offense Category']
# Create a new column counting the number of occurrence of crime category x race
df_suspects['Off_Cat_Counts'] = df_suspects.groupby(['Neighborhood', 'Race_OffenseCat']).transform('size')
pivot_offcat_race = df_suspects.pivot_table(index = 'Neighborhood', columns = 'Race_OffenseCat', values = 'Off_Cat_Counts', aggfunc = 'sum', fill_value = 0)
df_suspects_new = pd.merge(pivot_offcat_race, pivot_off_race, 
                     left_index=True, right_index=True)

# Reset index to make 'Neighborhood' a column again
df_suspects_new = df_suspects_new.reset_index()
df_suspects_new = pd.merge(df_suspects_new, pivot_off_type, on = 'Neighborhood', how = 'outer')

# COMBINE VICTIMS AND SUSPECTS DATA INTO ONE DATAFRAME
combined_crime_df = pd.merge(df_victims_new, df_suspects_new, on = 'Neighborhood', suffixes = ('_vic', '_sus'))
# Export to CSV
combined_crime_df.to_csv('combined_crime_df.csv', index = False)

# %%
pivot_vic_offrace.head()
# Out:
# Race_Offense       AI_AN_total_aggravated_assault  AI_AN_total_homicide  \
# Neighborhood
# alcott park                                     0                     0
# alverno                                         0                     0
# amani                                           0                     0
# arlington gardens                               0                     0
# arlington heights                               1                     0
#
# Race_Offense       AI_AN_total_partIIperson  AI_AN_total_rape  \
# Neighborhood
# alcott park                               0                 0
# alverno                                   0                 0
# amani                                     4                 0
# arlington gardens                         0                 0
# arlington heights                         1                 0
#
# Race_Offense       AI_AN_total_robbery  Asian_total_aggravated_assault  \
# Neighborhood
# alcott park                          0                               0
# alverno                              0                               0
# amani                                0                               0
# arlington gardens                    0                               0
# arlington heights                    0                               9
#
# Race_Offense       Asian_total_homicide  Asian_total_partIIperson  \
# Neighborhood
# alcott park                           0                         0
# alverno                               0                         0
# amani                                 0                         0
# arlington gardens                     0                         1
# arlington heights                     0                         0
#
# Race_Offense       Asian_total_rape  Asian_total_robbery  ...  \
# Neighborhood                                              ...
# alcott park                       0                    0  ...
# alverno                           0                    0  ...
# amani                             0                    0  ...
# arlington gardens                 0                    0  ...
# arlington heights                 0                    4  ...
#
# Race_Offense       other_total_human_trafficking  other_total_partIIperson  \
# Neighborhood
# alcott park                                    0                         0
# alverno                                        0                         0
# amani                                          0                         0
# arlington gardens                              0                         0
# arlington heights                              0                         0
#
# Race_Offense       other_total_rape  other_total_robbery  \
# Neighborhood
# alcott park                       0                    0
# alverno                           0                    0
# amani                             0                    0
# arlington gardens                 0                    0
# arlington heights                 0                    0
#
# Race_Offense       white_total_aggravated_assault  white_total_homicide  \
# Neighborhood
# alcott park                                     0                     0
# alverno                                        16                     0
# amani                                          25                     0
# arlington gardens                              49                     1
# arlington heights                             324                     0
#
# Race_Offense       white_total_human_trafficking  white_total_partIIperson  \
# Neighborhood
# alcott park                                    0                         9
# alverno                                        0                        64
# amani                                          0                        25
# arlington gardens                              0                       121
# arlington heights                              1                       361
#
# Race_Offense       white_total_rape  white_total_robbery
# Neighborhood
# alcott park                       0                    0
# alverno                           0                    0
# amani                             0                    0
# arlington gardens                 0                   16
# arlington heights                16                   16
#
# [5 rows x 36 columns]

# %% [markdown]
# ##### Merge neighborhood_estimates with victims and suspects data

# %%
neighborhood_vicsus_est = pd.merge(neighborhood_estimates, combined_crime_df, on = 'Neighborhood', how = 'inner')
neighborhood_vicsus_est.to_csv('neighborhood_vicsus_est.csv', index = False)

# %% [markdown]
# # Bringing in the Pedestrian Dataframe

# %%
df_ped = pd.read_stata("C:/Users/blah/blah/Documents/Data/WI_RAD/persons_fionly_geolocated_foranalysis_2022-2023.dta")

# Rename the neighborhood column to Neighborhood
df_ped = df_ped.rename(columns = {'neighborhood':'Neighborhood'})
# Replace 'nan' (string) with np.nan
df_ped['Neighborhood'] = df_ped['Neighborhood'].replace('nan', np.nan)
# Convert the 'Neighborhood' column to string values and then apply string methods
df_ped['Neighborhood'] = df_ped['Neighborhood'].fillna('').apply(str)
df_ped['Neighborhood'] = df_ped['Neighborhood'].str.strip().str.lower()
# Drop rows where 'Neighborhood' is either NaN or an empty string
df_ped = df_ped[df_ped['Neighborhood'].str.strip() != '']
df_ped = df_ped[df_ped['Neighborhood'] != '1_could not locate']

# %%
## Figuring out the count of pedestrian encounters in each neighborhood
PedNeigh_counts = df_ped.groupby('Neighborhood').size().reset_index(name='ped_count')

# %% [markdown]
# # Bringing in the Vehicles/Encounter Dataframe

# %%
df_enc = pd.read_stata("C:/Users/blah/blah/Documents/Data/WI_RAD/ts_encounters_analysis_updated key variables_2022-2023.dta")

# Rename the neighborhood column to Neighborhood
df_enc = df_enc.rename(columns = {'neighborhood':'Neighborhood'})
# Replace 'nan' (string) with np.nan
df_enc['Neighborhood'] = df_enc['Neighborhood'].replace('nan', np.nan)
# Convert the 'Neighborhood' column to string values and then apply string methods
df_enc['Neighborhood'] = df_enc['Neighborhood'].fillna('').apply(str)
df_enc['Neighborhood'] = df_enc['Neighborhood'].str.strip().str.lower()
# Drop rows where 'Neighborhood' is either NaN or an empty string
df_enc = df_enc[df_enc['Neighborhood'].str.strip() != '']
df_enc = df_enc[df_enc['Neighborhood'] != '1_could not locate']

# %%
## Figuring out the count of vehicle encounters in each neighborhood
EncNeigh_counts = df_enc.groupby('Neighborhood').size().reset_index(name='enc_count')

# %% [markdown]
# ##### Creating a dataframe with neighborhood estimates, victims and suspects, and pedestrian and vehicle counts

# %%
neighborhood_vicsus_pedenc_est = pd.merge(neighborhood_vicsus_est, EncNeigh_counts, on = 'Neighborhood', how = 'inner')
neighborhood_vicsus_pedenc_est = pd.merge(neighborhood_vicsus_pedenc_est, PedNeigh_counts, on = 'Neighborhood', how = 'inner')
neighborhood_vicsus_pedenc_est.to_csv('neighborhood_vicsus_pedenc_est.csv', index = False)

# %% [markdown]
# # New Dataframe with Pedestrians as the Unit of Analysis (df_ped)

# %% [markdown]
# ### Start with creating a count of victims by race in the df_victims dataframe

# %%
# race of victims count by neighborhoods
race_vic_neigh = df_victims.groupby(['Neighborhood', 'Race-Ethnicity']).size().unstack(fill_value=0).reset_index()

race_vic_neigh = race_vic_neigh.rename(columns = {'AI_AN' : 'AI_AN_viccnt',
                                                  'Asian': 'Asian_viccnt',
                                                  'NH_PI': 'NH_PI_viccnt',
                                                  'black':'black_viccnt',
                                                  'white' : 'white_viccnt',
                                                  'other' : 'other_viccnt',
                                                  'hispanic':'hispanic_viccnt'})

# %% [markdown]
# ### Creating a count of pedestrian stops by race in the df_ped dataframe

# %%
# Use cat.rename_categories to rename 'missing' to NaN
df_ped['racecat'] = df_ped['racecat'].cat.remove_categories('missing')

race_count_neigh = df_ped.pivot_table(index = 'Neighborhood', columns = 'racecat', aggfunc = 'size', fill_value = 0, observed = True)

race_count_neigh = race_count_neigh.rename(columns = {'white' : 'white_peds', 'black' : 'black_peds',
                                                      'latinx' : 'hispanic_peds', 
                                                      'other' : 'other_peds'})

# Reset the index so that 'neighborhood' becomes a column
race_count_neigh = race_count_neigh.reset_index()

# %%
col_printing(race_count_neigh)
# Out:
# 0 Neighborhood
# 1 white_peds
# 2 black_peds
# 3 hispanic_peds
# 4 other_peds

# %% [markdown]
# ##### Merge the race_count_neigh and race_vic_neigh dataframe together

# %%
vic_ped_count = pd.merge(race_vic_neigh, race_count_neigh, on = 'Neighborhood', how = 'inner')

# %%
col_printing(vic_ped_count)
# Out:
# 0 Neighborhood
# 1 AI_AN_viccnt
# 2 Asian_viccnt
# 3 NH_PI_viccnt
# 4 black_viccnt
# 5 hispanic_viccnt
# 6 other_viccnt
# 7 white_viccnt
# 8 white_peds
# 9 black_peds
# 10 hispanic_peds
# 11 other_peds

# %% [markdown]
# ## Forming the pedestrian df with victim counts and pedestrian counts

# %%
df_ped_vic_count = pd.merge(df_ped, vic_ped_count, on = 'Neighborhood', how = 'inner')
df_ped_vic_count.to_csv("df_ped_vic_count.csv", index = False)

# %% [markdown]
# ## Forming the pedestrian df (unit of analysis) with victim counts, pedestrian counts, and neighborhood details

# %%
df_ped_vic_count_neigh = pd.merge(df_ped_vic_count, neighborhood_estimates, on = 'Neighborhood', how = 'inner')
df_ped_vic_count_neigh.to_csv("df_ped_vic_count_neigh.csv", index = False)

# %%
col_printing(df_ped_vic_count_neigh)
# Out:
# 0 top10neighborhood
# 1 Neighborhood
# 2 searchperformed
# 3 pcsearch
# 4 incidentarrestsearch
# 5 contactdesc1a
# 6 stop_justificationa
# 7 stop_justificationb
# 8 search_justificationa
# 9 search_justificationb
# 10 uniqueperson
# 11 top20neighborhood
# 12 call_no
# 13 sexcat
# 14 racecat
# 15 agecat
# 16 agecontinuous
# 17 young_old
# 18 timeofday
# 19 morning
# 20 afternoon
# 21 firstevening
# 22 secondevening
# 23 latitudea1
# 24 longitudea1
# 25 street
# 26 city
# 27 state
# 28 district
# 29 stoptype
# 30 violentstop
# 31 violent_weapon
# 32 violent_other
# 33 propertystop
# 34 drugdealingstop
# 35 roadsafetystop
# 36 equipmentstop
# 37 publicdisorderstop
# 38 wantedorwarrantstop
# 39 trafficstop
# 40 possweaponstop
# 41 possdrugstop
# 42 otherstop
# 43 missingstop
# 44 violation_typea
# 45 searcharrest
# 46 searchnofrisk
# 47 friskperformed
# 48 searchandfrisk
# 49 frisktype
# 50 friskarrest
# 51 contrabandretrieved
# 52 stopoutcome
# 53 top20officer
# 54 top20unit
# 55 officers
# 56 officers2
# 57 officers3
# 58 officername1a
# 59 officername2a
# 60 officername3a
# 61 officername4a
# 62 officername5a
# 63 officername6a
# 64 officername7a
# 65 officername8a
# 66 officername9a
# 67 officername10a
# 68 officername11a
# 69 officername12a
# 70 officername13a
# 71 officername14a
# 72 officername15a
# 73 officername16a
# 74 officername17a
# 75 officername18a
# 76 officername19a
# 77 officername20a
# 78 officername21a
# 79 officername22a
# 80 officername23a
# 81 officername24a
# 82 officername25a
# 83 officername26a
# 84 officername27a
# 85 officername28a
# 86 officername29a
# 87 officername30a
# 88 officername31a
# 89 officername32a
# 90 officername33a
# 91 officername34a
# 92 officername35a
# 93 officername36a
# 94 officername37a
# 95 officername38a
# 96 officername39a
# 97 officername40a
# 98 officername41a
# 99 officername42a
# 100 officername43a
# 101 officername44a
# 102 officername45a
# 103 officername46a
# 104 officername47a
# 105 officername48a
# 106 officername49a
# 107 officername50a
# 108 officername51a
# 109 officername52a
# 110 officername53a
# 111 officername54a
# 112 officername55a
# 113 officername56a
# 114 officername57a
# 115 officername58a
# 116 officername59a
# 117 officername60a
# 118 officername61a
# 119 officername62a
# 120 officername63a
# 121 officername64a
# 122 officername65a
# 123 officername66a
# 124 officername67a
# 125 officername68a
# 126 officername69a
# 127 officername70a
# 128 officername71a
# 129 officername72a
# 130 officername73a
# 131 officername74a
# 132 officername75a
# 133 officername76a
# 134 officername77a
# 135 officername78a
# 136 officername81a
# 137 officername82a
# 138 officername83a
# 139 officername84a
# 140 officername87a
# 141 officername88a
# 142 officername89a
# 143 officername90a
# 144 officername92a
# 145 officername93a
# 146 officername94a
# 147 officername95a
# 148 officername96a
# 149 officername97a
# 150 officername99a
# 151 officername102a
# 152 officername103a
# 153 officername104a
# 154 officername105a
# 155 officername106a
# 156 officername107a
# 157 officername109a
# 158 officername110a
# 159 officername111a
# 160 officername113a
# 161 officername115a
# 162 officername116a
# 163 officername118a
# 164 officername119a
# 165 officername120a
# 166 officername121a
# 167 officername122a
# 168 officername124a
# 169 officername125a
# 170 officername126a
# 171 officername127a
# 172 officername128a
# 173 officername129a
# 174 officername130a
# 175 officername131a
# 176 officername132a
# 177 officername135a
# 178 officername136a
# 179 officername139a
# 180 officername140a
# 181 officername141a
# 182 officername142a
# 183 officername144a
# 184 officername145a
# 185 officername147a
# 186 officername148a
# 187 officername150a
# 188 officername151a
# 189 officername153a
# 190 officername154a
# 191 officername155a
# 192 officername157a
# 193 officername158a
# 194 officername159a
# 195 officername160a
# 196 officername161a
# 197 officername162a
# 198 officername163a
# 199 officername164a
# 200 officername165a
# 201 officername166a
# 202 officername168a
# 203 officername169a
# 204 officername170a
# 205 officername171a
# 206 officername172a
# 207 officername173a
# 208 officername174a
# 209 officername175a
# 210 officername177a
# 211 officername179a
# 212 officername180a
# 213 officername181a
# 214 officername182a
# 215 officername183a
# 216 officername184a
# 217 officername185a
# 218 officername79a
# 219 officername80a
# 220 officername85a
# 221 officername86a
# 222 officername91a
# 223 officername98a
# 224 officername101a
# 225 officername108a
# 226 officername112a
# 227 officername114a
# 228 officername117a
# 229 officername133a
# 230 officername134a
# 231 officername137a
# 232 officername138a
# 233 officername143a
# 234 officername146a
# 235 officername152a
# 236 officername156a
# 237 officername167a
# 238 officername176a
# 239 officername178a
# 240 officername186a
# 241 officername187a
# 242 officername188a
# 243 officername189a
# 244 officername190a
# 245 officername191a
# 246 officername192a
# 247 officername193a
# 248 officername194a
# 249 officername196a
# 250 officername197a
# 251 officername198a
# 252 officername199a
# 253 officername200a
# 254 officername202a
# 255 officername203a
# 256 officername204a
# 257 officername205a
# 258 officername206a
# 259 officername207a
# 260 officername208a
# 261 officername209a
# 262 officername210a
# 263 officername211a
# 264 officername213a
# 265 officername214a
# 266 officername215a
# 267 officername217a
# 268 officername218a
# 269 officername220a
# 270 officername221a
# 271 officername222a
# 272 officername224a
# 273 officername225a
# 274 officername226a
# 275 officername227a
# 276 officername228a
# 277 officername229a
# 278 officername230a
# 279 officername231a
# 280 officername232a
# 281 officername233a
# 282 officername234a
# 283 officername235a
# 284 officername236a
# 285 officername237a
# 286 officername238a
# 287 officername239a
# 288 officername240a
# 289 officername241a
# 290 officername242a
# 291 officername243a
# 292 officername244a
# 293 officername1b
# 294 officername2b
# 295 officername3b
# 296 officername4b
# 297 officername5b
# 298 officername6b
# 299 officername7b
# 300 officername8b
# 301 officername9b
# 302 officername10b
# 303 officername11b
# 304 officername12b
# 305 officername13b
# 306 officername14b
# 307 officername15b
# 308 officername16b
# 309 officername17b
# 310 officername18b
# 311 officername19b
# 312 officername20b
# 313 officername21b
# 314 officername22b
# 315 officername23b
# 316 officername24b
# 317 officername25b
# 318 officername26b
# 319 officername27b
# 320 officername28b
# 321 officername29b
# 322 officername30b
# 323 officername31b
# 324 officername32b
# 325 officername33b
# 326 officername34b
# 327 officername35b
# 328 officername36b
# 329 officername37b
# 330 officername38b
# 331 officername39b
# 332 officername40b
# 333 officername41b
# 334 officername42b
# 335 officername43b
# 336 officername44b
# 337 officername45b
# 338 officername46b
# 339 officername47b
# 340 officername48b
# 341 officername49b
# 342 officername50b
# 343 officername51b
# 344 officername100a
# 345 officername123a
# 346 officername149a
# 347 officername1c
# 348 officername2c
# 349 officername3c
# 350 officername4c
# 351 officername5c
# 352 officername6c
# 353 officername7c
# 354 officername195a
# 355 officername201a
# 356 officername212a
# 357 officername216a
# 358 officername219a
# 359 officername8c
# 360 officername11c
# 361 officername12c
# 362 officername13c
# 363 officername14c
# 364 officername15c
# 365 officername16c
# 366 employee_name1a
# 367 employee_name2a
# 368 employee_name3a
# 369 employee_name4a
# 370 employee_name5a
# 371 employee_name6a
# 372 employee_name7a
# 373 employee_name8a
# 374 employee_name9a
# 375 employee_name10a
# 376 employee_name11a
# 377 employee_name12a
# 378 employee_name13a
# 379 employee_name14a
# 380 employee_name15a
# 381 employee_name16a
# 382 employee_name17a
# 383 employee_name18a
# 384 employee_name19a
# 385 employee_name20a
# 386 employee_name21a
# 387 employee_name22a
# 388 employee_name23a
# 389 employee_name24a
# 390 employee_name25a
# 391 employee_name26a
# 392 employee_name27a
# 393 employee_name28a
# 394 employee_name29a
# 395 employee_name30a
# 396 employee_name1b
# 397 employee_name2b
# 398 employee_name3b
# 399 employee_name4b
# 400 employee_name5b
# 401 employee_name6b
# 402 employee_name7b
# 403 employee_name8b
# 404 employee_name9b
# 405 employee_name10b
# 406 employee_name11b
# 407 employee_name12b
# 408 employee_name13b
# 409 employee_name14b
# 410 employee_name15b
# 411 employee_name16b
# 412 employee_name17b
# 413 employee_name18b
# 414 employee_name19b
# 415 employee_name20b
# 416 employee_name21b
# 417 employee_name22b
# 418 employee_name23b
# 419 employee_name24b
# 420 employee_name25b
# 421 employee_name26b
# 422 employee_name27b
# 423 employee_name28b
# 424 employee_name29b
# 425 employee_name30b
# 426 employee_name1c
# 427 employee_name2c
# 428 employee_name3c
# 429 employee_name4c
# 430 employee_name5c
# 431 employee_name6c
# 432 unit_id1
# 433 unit_id2
# 434 unit_id3
# 435 unit_id4
# 436 unit_id5
# 437 unit_id6
# 438 unit_id7
# 439 unit_id8
# 440 unit_id9
# 441 unit_id10
# 442 unit_id11
# 443 unit_id12
# 444 unit_id13
# 445 unit_id14
# 446 unit_id15
# 447 unit_id16
# 448 unit_id17
# 449 unit_id18
# 450 unit_id19
# 451 unit_id20
# 452 unit_id21
# 453 unit_id22
# 454 unit_id23
# 455 unit_id24
# 456 unit_id25
# 457 unit_id26
# 458 unit_id27
# 459 unit_id28
# 460 unit_id29
# 461 unit_id30
# 462 unit_id31
# 463 unit_id32
# 464 unit_id33
# 465 unit_id34
# 466 unit_id35
# 467 unit_id36
# 468 unit_id37
# 469 unit_id38
# 470 unit_id39
# 471 unit_id40
# 472 unit_id41
# 473 unit_id42
# 474 unit_id43
# 475 unit_id44
# 476 unit_id45
# 477 unit_id46
# 478 unit_id47
# 479 unit_id48
# 480 unit_id49
# 481 unit_id50
# 482 unit_id51
# 483 unit_id52
# 484 unit_id53
# 485 unit_id54
# 486 unit_id55
# 487 unit_id56
# 488 unit_id57
# 489 unit_id58
# 490 unit_id59
# 491 unit_id60
# 492 unit_id61
# 493 unit_id62
# 494 unit_id63
# 495 unit_id64
# 496 unit_id65
# 497 unit_id66
# 498 unit_id67
# 499 unit_id68
# 500 unit_id69
# 501 unit_id70
# 502 unit_id71
# 503 unit_id72
# 504 unit_id73
# 505 unit_id74
# 506 unit_id75
# 507 unit_id76
# 508 unit_id77
# 509 unit_id78
# 510 unit_id79
# 511 unit_id80
# 512 unit_id81
# 513 unit_id82
# 514 unit_id83
# 515 unit_id84
# 516 unit_id85
# 517 unit_id86
# 518 unit_id87
# 519 unit_id88
# 520 unit_id89
# 521 unit_id90
# 522 unit_id91
# 523 unit_id92
# 524 unit_id93
# 525 unit_id94
# 526 unit_id95
# 527 unit_id96
# 528 unit_id97
# 529 unit_id98
# 530 unit_id99
# 531 unit_id100
# 532 unit_id101
# 533 unit_id102
# 534 unit_id103
# 535 unit_id104
# 536 unit_id105
# 537 unit_id106
# 538 unit_id107
# 539 unit_id108
# 540 unit_id109
# 541 unit_id110
# 542 unit_id111
# 543 unit_id112
# 544 unit_id113
# 545 unit_id114
# 546 unit_id115
# 547 unit_id116
# 548 unit_id117
# 549 unit_id118
# 550 unit_id119
# 551 unit_id120
# 552 unit_id121
# 553 unit_id122
# 554 unit_id123
# 555 unit_id124
# 556 unit_id125
# 557 unit_id126
# 558 unit_id127
# 559 unit_id128
# 560 unit_id129
# 561 unit_id130
# 562 unit_id131
# 563 unit_id132
# 564 unit_id133
# 565 unit_id134
# 566 unit_id135
# 567 unit_id136
# 568 unit_id137
# 569 unit_id138
# 570 unit_id139
# 571 unit_id140
# 572 unit_id141
# 573 unit_id142
# 574 unit_id143
# 575 unit_id144
# 576 unit_id145
# 577 unit_id146
# 578 unit_id147
# 579 unit_id148
# 580 unit_id149
# 581 unit_id150
# 582 unit_id151
# 583 unit_id152
# 584 unit_id153
# 585 unit_id154
# 586 unit_id155
# 587 unit_id156
# 588 unit_id157
# 589 unit_id158
# 590 unit_id159
# 591 unit_id160
# 592 unit_id161
# 593 unit_id162
# 594 unit_id163
# 595 unit_id164
# 596 unit_id165
# 597 unit_id166
# 598 unit_id167
# 599 unit_id168
# 600 unit_id169
# 601 unit_id170
# 602 unit_id171
# 603 unit_id172
# 604 unit_id173
# 605 officernamesmerge
# 606 sex_codea
# 607 race_descriptiona
# 608 race_descriptionb
# 609 ethnicity_descriptiona
# 610 age_codea
# 611 calltype_origa
# 612 calltype_origb
# 613 contactdesc2a
# 614 contactdesc3a
# 615 contactdesc4a
# 616 contactdesc5a
# 617 contactdesc6a
# 618 contactdesc7a
# 619 contactdesc8a
# 620 contactdesc9a
# 621 contactdesc10a
# 622 contactdesc11a
# 623 contactdesc12a
# 624 latitude
# 625 longitude
# 626 lat_a
# 627 long_a
# 628 address_streetaddressa
# 629 address_streetaddressb
# 630 address_streetaddressc
# 631 location_addressa
# 632 location_addressb
# 633 location_addressc
# 634 calltype_finala
# 635 calltype_finalb
# 636 search_results_descriptiona
# 637 search_results_descriptionb
# 638 individualcontraband1a
# 639 individualcontraband2a
# 640 individualcontraband3a
# 641 individualothercontraband1a
# 642 individualothercontraband2a
# 643 individualothercontraband3a
# 644 vehiclecontraband11a
# 645 vehiclecontraband12a
# 646 vehiclecontraband13a
# 647 vehicleothercontraband11a
# 648 vehicleothercontraband12a
# 649 vehicleothercontraband13a
# 650 search_results_descriptionc
# 651 le_action_descriptiona
# 652 summaryreason1a
# 653 summaryreason2a
# 654 summaryreason3a
# 655 summaryreasondetail1a
# 656 summaryreasondetail2a
# 657 summaryreasondetail3a
# 658 summaryotherreason1a
# 659 summaryotherreason2a
# 660 summaryotherreason3a
# 661 summaryotherreasondetail1a
# 662 summaryotherreasondetail2a
# 663 summaryotherreasondetail3a
# 664 summaryoutcome1a
# 665 summaryoutcome2a
# 666 summaryoutcome3a
# 667 summaryoutcome4a
# 668 anysearch
# 669 search_nofrisk
# 670 friskandarrest
# 671 warning_citation_onlya
# 672 warningsnuma
# 673 warning_narrative1a
# 674 warning_narrative2a
# 675 warning_narrative3a
# 676 warning_narrative4a
# 677 warning_narrative5a
# 678 warning_narrative6a
# 679 warning_narrative7a
# 680 warning_narrative8a
# 681 warning_narrative9a
# 682 squadnuma
# 683 squadnumb
# 684 squadnumc
# 685 unitmerge
# 686 identifier
# 687 sampletag
# 688 frisksample
# 689 ioars
# 690 race_ethnicity
# 691 sex
# 692 age1
# 693 quarter
# 694 encounterform
# 695 encounter
# 696 encountertypea
# 697 encountertypeb
# 698 encounterdate
# 699 encounterdatetime
# 700 encounterdatetime2a
# 701 encounterdatetime3a
# 702 encounterdatetime4a
# 703 encounterdatetime5a
# 704 encounterdatetime6a
# 705 encounterdate3a
# 706 encounterdate4a
# 707 encounterdate5a
# 708 encounterdate6a
# 709 encounterdatetimeb
# 710 incident_date1a
# 711 incident_date2a
# 712 incident_date3a
# 713 incident_date4a
# 714 incident_date5a
# 715 incident_date6a
# 716 incident_date7a
# 717 incident_date8a
# 718 incident_date9a
# 719 incident_date10a
# 720 incident_date11a
# 721 incident_date12a
# 722 incident_date13a
# 723 incident_date14a
# 724 incident_date15a
# 725 incident_date16a
# 726 incident_date17a
# 727 incident_date18a
# 728 incident_date19a
# 729 incident_date20a
# 730 incident_date21a
# 731 incident_date22a
# 732 incident_date23a
# 733 incident_date24a
# 734 incident_date25a
# 735 incident_date26a
# 736 incident_date27a
# 737 incident_date28a
# 738 incident_date29a
# 739 incident_date30a
# 740 incident_date1b
# 741 incident_date2b
# 742 incident_date3b
# 743 incident_date4b
# 744 incident_date5b
# 745 incident_date6b
# 746 incident_date7b
# 747 incident_date8b
# 748 incident_date9b
# 749 incident_date10b
# 750 incident_date11b
# 751 incident_date12b
# 752 incident_date13b
# 753 incident_date14b
# 754 incident_date15b
# 755 incident_date16b
# 756 incident_date17b
# 757 incident_date18b
# 758 incident_date19b
# 759 incident_date20b
# 760 incident_date21b
# 761 incident_date22b
# 762 incident_date23b
# 763 incident_date24b
# 764 incident_date25b
# 765 incident_date26b
# 766 incident_date27b
# 767 incident_date28b
# 768 incident_date29b
# 769 incident_date30b
# 770 mnia
# 771 mni_fia
# 772 mni_fib
# 773 tracs_race
# 774 tracs_sex
# 775 dateofbirth
# 776 call_no_origa
# 777 call_nob
# 778 call_no_origb
# 779 callkeya
# 780 callkeynuma
# 781 callkeyb
# 782 callkeynumb
# 783 fi_officernuma
# 784 fi_officernumb
# 785 nae_officernuma
# 786 tracs_personnuma
# 787 finuma
# 788 finumb
# 789 fi_personnuma
# 790 fi_personnumb
# 791 naenuma
# 792 naenumb
# 793 nae_personnuma
# 794 ntcnuma
# 795 elcinuma
# 796 contactsummarynuma
# 797 fieldinterviewsa
# 798 fieldinterviewsb
# 799 naesa
# 800 naepersona
# 801 naeperson_ida
# 802 naepersonb
# 803 fipersona
# 804 fiperson_ida
# 805 fipersonb
# 806 fiperson_idb
# 807 tracspersona
# 808 tracspersonb
# 809 cadonlypersona
# 810 cadonlypersonb
# 811 aimonlypersona
# 812 aimonlypersonb
# 813 tracsform1a
# 814 tracsform2a
# 815 tracsform3a
# 816 tracsform4a
# 817 tracsform5a
# 818 tracsform6a
# 819 tracsform7a
# 820 tracsform8a
# 821 tracsform9a
# 822 tracsform10a
# 823 tracsform11a
# 824 tracsform12a
# 825 casenumber1a
# 826 casenumber2a
# 827 casenumber3a
# 828 casenumber4a
# 829 casenumber5a
# 830 casenumber6a
# 831 casenumber7a
# 832 casenumber8a
# 833 casenumber9a
# 834 casenumber10a
# 835 casenumber11a
# 836 casenumber12a
# 837 status1a
# 838 status2a
# 839 status3a
# 840 status4a
# 841 status5a
# 842 status6a
# 843 status7a
# 844 status8a
# 845 status9a
# 846 status10a
# 847 status11a
# 848 status12a
# 849 citation_ord_desc1a
# 850 citation_ord_desc2a
# 851 citation_ord_desc3a
# 852 citation_ord_desc4a
# 853 citation_ord_desc5a
# 854 citation_ord_desc6a
# 855 citation_ord_desc7a
# 856 citation_ord_desc8a
# 857 citation_ord_desc9a
# 858 citation_ord_desc10a
# 859 citation_ord_desc11a
# 860 citation_ord_desc12a
# 861 citation_ord_number1a
# 862 citation_ord_number2a
# 863 citation_ord_number3a
# 864 citation_ord_number4a
# 865 citation_ord_number5a
# 866 citation_ord_number6a
# 867 citation_ord_number7a
# 868 citation_ord_number8a
# 869 citation_ord_number9a
# 870 citation_ord_number10a
# 871 citation_ord_number11a
# 872 citation_ord_number12a
# 873 citation_statute_desc1a
# 874 citation_statute_desc2a
# 875 citation_statute_desc3a
# 876 citation_statute_desc4a
# 877 citation_statute_desc5a
# 878 citation_statute_desc6a
# 879 citation_statute_desc7a
# 880 citation_statute_desc8a
# 881 citation_statute_desc9a
# 882 citation_statute_desc10a
# 883 citation_statute_desc11a
# 884 citation_statute_desc12a
# 885 citation_statute_number1a
# 886 citation_statute_number2a
# 887 citation_statute_number3a
# 888 citation_statute_number4a
# 889 citation_statute_number5a
# 890 citation_statute_number6a
# 891 citation_statute_number7a
# 892 citation_statute_number8a
# 893 citation_statute_number9a
# 894 citation_statute_number10a
# 895 citation_statute_number11a
# 896 citation_statute_number12a
# 897 warning_ord_desc11a
# 898 warning_ord_desc21a
# 899 warning_ord_desc31a
# 900 warning_ord_desc12a
# 901 warning_ord_desc22a
# 902 warning_ord_desc32a
# 903 warning_ord_desc42a
# 904 warning_ord_desc52a
# 905 warning_ord_desc13a
# 906 warning_ord_desc23a
# 907 warning_ord_desc33a
# 908 warning_ord_desc43a
# 909 warning_ord_desc14a
# 910 warning_ord_desc24a
# 911 warning_ord_desc34a
# 912 warning_ord_desc15a
# 913 warning_ord_desc25a
# 914 warning_ord_desc35a
# 915 warning_ord_desc45a
# 916 warning_ord_desc16a
# 917 warning_ord_desc26a
# 918 warning_ord_desc17a
# 919 warning_ord_desc18a
# 920 warning_ord_desc44a
# 921 warning_ord_number11a
# 922 warning_ord_number21a
# 923 warning_ord_number31a
# 924 warning_ord_number12a
# 925 warning_ord_number22a
# 926 warning_ord_number32a
# 927 warning_ord_number42a
# 928 warning_ord_number52a
# 929 warning_ord_number13a
# 930 warning_ord_number23a
# 931 warning_ord_number33a
# 932 warning_ord_number43a
# 933 warning_ord_number14a
# 934 warning_ord_number24a
# 935 warning_ord_number34a
# 936 warning_ord_number15a
# 937 warning_ord_number25a
# 938 warning_ord_number35a
# 939 warning_ord_number45a
# 940 warning_ord_number16a
# 941 warning_ord_number26a
# 942 warning_ord_number17a
# 943 warning_ord_number18a
# 944 warning_ord_number44a
# 945 warning_statute_desc11a
# 946 warning_statute_desc21a
# 947 warning_statute_desc31a
# 948 warning_statute_desc12a
# 949 warning_statute_desc22a
# 950 warning_statute_desc32a
# 951 warning_statute_desc42a
# 952 warning_statute_desc52a
# 953 warning_statute_desc13a
# 954 warning_statute_desc23a
# 955 warning_statute_desc33a
# 956 warning_statute_desc43a
# 957 warning_statute_desc14a
# 958 warning_statute_desc24a
# 959 warning_statute_desc34a
# 960 warning_statute_desc15a
# 961 warning_statute_desc25a
# 962 warning_statute_desc35a
# 963 warning_statute_desc45a
# 964 warning_statute_desc16a
# 965 warning_statute_desc26a
# 966 warning_statute_desc17a
# 967 warning_statute_desc18a
# 968 warning_statute_desc44a
# 969 warning_statute_number11a
# 970 warning_statute_number21a
# 971 warning_statute_number31a
# 972 warning_statute_number12a
# 973 warning_statute_number22a
# 974 warning_statute_number32a
# 975 warning_statute_number42a
# 976 warning_statute_number52a
# 977 warning_statute_number13a
# 978 warning_statute_number23a
# 979 warning_statute_number33a
# 980 warning_statute_number43a
# 981 warning_statute_number14a
# 982 warning_statute_number24a
# 983 warning_statute_number34a
# 984 warning_statute_number15a
# 985 warning_statute_number25a
# 986 warning_statute_number35a
# 987 warning_statute_number45a
# 988 warning_statute_number16a
# 989 warning_statute_number26a
# 990 warning_statute_number17a
# 991 warning_statute_number18a
# 992 warning_statute_number44a
# 993 individualconsentreceived1a
# 994 individualconsentreceived2a
# 995 individualconsentreceived3a
# 996 individualconsentreceived4a
# 997 individualconsentrequested1a
# 998 individualconsentrequested2a
# 999 individualconsentrequested3a
# 1000 individualconsentrequested4a
# 1001 individualsearchconducted1a
# 1002 individualsearchconducted2a
# 1003 individualsearchconducted3a
# 1004 individualsearchconducted4a
# 1005 vehicleconsentreceived11a
# 1006 vehicleconsentreceived21a
# 1007 vehicleconsentreceived31a
# 1008 vehicleconsentreceived41a
# 1009 vehicleconsentreceived12a
# 1010 vehicleconsentreceived22a
# 1011 vehicleconsentreceived32a
# 1012 vehicleconsentreceived42a
# 1013 vehicleconsentreceived13a
# 1014 vehicleconsentreceived23a
# 1015 vehicleconsentreceived33a
# 1016 vehicleconsentreceived43a
# 1017 vehicleconsentreceived14a
# 1018 vehicleconsentreceived24a
# 1019 vehicleconsentreceived34a
# 1020 vehicleconsentreceived44a
# 1021 vehicleconsentrequested11a
# 1022 vehicleconsentrequested21a
# 1023 vehicleconsentrequested31a
# 1024 vehicleconsentrequested41a
# 1025 vehicleconsentrequested12a
# 1026 vehicleconsentrequested22a
# 1027 vehicleconsentrequested32a
# 1028 vehicleconsentrequested42a
# 1029 vehicleconsentrequested13a
# 1030 vehicleconsentrequested23a
# 1031 vehicleconsentrequested33a
# 1032 vehicleconsentrequested43a
# 1033 vehicleconsentrequested14a
# 1034 vehicleconsentrequested24a
# 1035 vehicleconsentrequested34a
# 1036 vehicleconsentrequested44a
# 1037 pat_down_descriptiona
# 1038 pat_down_descriptionb
# 1039 patdown_justificationa
# 1040 patdown_justificationb
# 1041 patdown_justificationc
# 1042 calldatetimea
# 1043 calldatetimeb
# 1044 rep_dista
# 1045 rep_distb
# 1046 call_type_origa
# 1047 call_type_origb
# 1048 call_type_finala
# 1049 call_type_finalb
# 1050 created_datea
# 1051 created_dateb
# 1052 call_created_timea
# 1053 call_created_timeb
# 1054 groupa
# 1055 groupb
# 1056 prior_suspect_descriptiona
# 1057 prior_suspect_descriptionb
# 1058 suspect_descriptiona
# 1059 suspect_descriptionb
# 1060 elciorcs_narrative1a
# 1061 elciorcs_narrative2a
# 1062 elciorcs_narrative3a
# 1063 elciorcs_narrative4a
# 1064 elciorcs_narrative5a
# 1065 elciorcs_narrative6a
# 1066 elciorcs_narrative7a
# 1067 elciorcs_narrative8a
# 1068 elciorcs_narrative9a
# 1069 elciorcs_narrative10a
# 1070 elciorcs_narrative11a
# 1071 elciorcs_narrative12a
# 1072 ntc_narrative1a
# 1073 ntc_narrative2a
# 1074 ntc_narrative3a
# 1075 ntc_narrative4a
# 1076 ntc_narrative5a
# 1077 ntc_narrative6a
# 1078 uof_justificationa
# 1079 uof_justificationb
# 1080 use_of_force_descriptiona
# 1081 use_of_force_descriptionb
# 1082 dispositiona
# 1083 cad_dispositiona
# 1084 uof_report_number1a
# 1085 uof_report_number2a
# 1086 uof_report_number3a
# 1087 uof_report_number4a
# 1088 uof_report_number5a
# 1089 uof_report_number6a
# 1090 uof_report_number7a
# 1091 uof_report_number8a
# 1092 uof_report_number9a
# 1093 uof_report_number10a
# 1094 uof_report_number11a
# 1095 uof_report_number12a
# 1096 uof_report_number13a
# 1097 uof_report_number14a
# 1098 uof_report_number15a
# 1099 uof_report_number16a
# 1100 uof_report_number17a
# 1101 uof_report_number18a
# 1102 uof_report_number19a
# 1103 uof_report_number20a
# 1104 uof_report_number21a
# 1105 uof_report_number22a
# 1106 uof_report_number23a
# 1107 uof_report_number24a
# 1108 uof_report_number25a
# 1109 uof_report_number26a
# 1110 uof_report_number27a
# 1111 uof_report_number28a
# 1112 uof_report_number29a
# 1113 uof_report_number30a
# 1114 uof_report_number1b
# 1115 uof_report_number2b
# 1116 uof_report_number3b
# 1117 uof_report_number4b
# 1118 uof_report_number5b
# 1119 uof_report_number6b
# 1120 uof_report_number7b
# 1121 uof_report_number8b
# 1122 uof_report_number9b
# 1123 uof_report_number10b
# 1124 uof_report_number11b
# 1125 uof_report_number12b
# 1126 uof_report_number13b
# 1127 uof_report_number14b
# 1128 uof_report_number15b
# 1129 uof_report_number16b
# 1130 uof_report_number17b
# 1131 uof_report_number18b
# 1132 uof_report_number19b
# 1133 uof_report_number20b
# 1134 uof_report_number21b
# 1135 uof_report_number22b
# 1136 uof_report_number23b
# 1137 uof_report_number24b
# 1138 uof_report_number25b
# 1139 uof_report_number26b
# 1140 uof_report_number27b
# 1141 uof_report_number28b
# 1142 uof_report_number29b
# 1143 uof_report_number30b
# 1144 officer_activity1a
# 1145 officer_activity2a
# 1146 officer_activity3a
# 1147 officer_activity4a
# 1148 officer_activity5a
# 1149 officer_activity6a
# 1150 officer_activity7a
# 1151 officer_activity8a
# 1152 officer_activity9a
# 1153 officer_activity10a
# 1154 officer_activity11a
# 1155 officer_activity12a
# 1156 officer_activity13a
# 1157 officer_activity14a
# 1158 officer_activity15a
# 1159 officer_activity16a
# 1160 officer_activity17a
# 1161 officer_activity18a
# 1162 officer_activity19a
# 1163 officer_activity20a
# 1164 officer_activity21a
# 1165 officer_activity22a
# 1166 officer_activity23a
# 1167 officer_activity24a
# 1168 officer_activity25a
# 1169 officer_activity26a
# 1170 officer_activity27a
# 1171 officer_activity28a
# 1172 officer_activity29a
# 1173 officer_activity30a
# 1174 officer_activity1b
# 1175 officer_activity2b
# 1176 officer_activity3b
# 1177 officer_activity4b
# 1178 officer_activity5b
# 1179 officer_activity6b
# 1180 officer_activity7b
# 1181 officer_activity8b
# 1182 officer_activity9b
# 1183 officer_activity10b
# 1184 officer_activity11b
# 1185 officer_activity12b
# 1186 officer_activity13b
# 1187 officer_activity14b
# 1188 officer_activity15b
# 1189 officer_activity16b
# 1190 officer_activity17b
# 1191 officer_activity18b
# 1192 officer_activity19b
# 1193 officer_activity20b
# 1194 officer_activity21b
# 1195 officer_activity22b
# 1196 officer_activity23b
# 1197 officer_activity24b
# 1198 officer_activity25b
# 1199 officer_activity26b
# 1200 officer_activity27b
# 1201 officer_activity28b
# 1202 officer_activity29b
# 1203 officer_activity30b
# 1204 type_of_force1a
# 1205 type_of_force2a
# 1206 type_of_force3a
# 1207 type_of_force4a
# 1208 type_of_force5a
# 1209 type_of_force6a
# 1210 type_of_force7a
# 1211 type_of_force8a
# 1212 type_of_force9a
# 1213 type_of_force10a
# 1214 type_of_force11a
# 1215 type_of_force12a
# 1216 type_of_force13a
# 1217 type_of_force14a
# 1218 type_of_force15a
# 1219 type_of_force16a
# 1220 type_of_force17a
# 1221 type_of_force18a
# 1222 type_of_force19a
# 1223 type_of_force20a
# 1224 type_of_force21a
# 1225 type_of_force22a
# 1226 type_of_force23a
# 1227 type_of_force24a
# 1228 type_of_force25a
# 1229 type_of_force26a
# 1230 type_of_force27a
# 1231 type_of_force28a
# 1232 type_of_force29a
# 1233 type_of_force30a
# 1234 type_of_force1b
# 1235 type_of_force2b
# 1236 type_of_force3b
# 1237 type_of_force4b
# 1238 type_of_force5b
# 1239 type_of_force6b
# 1240 type_of_force7b
# 1241 type_of_force8b
# 1242 type_of_force9b
# 1243 type_of_force10b
# 1244 type_of_force11b
# 1245 type_of_force12b
# 1246 type_of_force13b
# 1247 type_of_force14b
# 1248 type_of_force15b
# 1249 type_of_force16b
# 1250 type_of_force17b
# 1251 type_of_force18b
# 1252 type_of_force19b
# 1253 type_of_force20b
# 1254 type_of_force21b
# 1255 type_of_force22b
# 1256 type_of_force23b
# 1257 type_of_force24b
# 1258 type_of_force25b
# 1259 type_of_force26b
# 1260 type_of_force27b
# 1261 type_of_force28b
# 1262 type_of_force29b
# 1263 type_of_force30b
# 1264 fieldinterview_ida
# 1265 fieldinterview_idb
# 1266 numbera
# 1267 numberb
# 1268 nae_ida
# 1269 entitytype1a
# 1270 entitytype2a
# 1271 entitytype3a
# 1272 entitytype4a
# 1273 entitytype5a
# 1274 entitytype6a
# 1275 entitytype7a
# 1276 entitytype8a
# 1277 entitytype9a
# 1278 segment_name1a
# 1279 segment_time_converted1a
# 1280 segment_narrative1a
# 1281 segment_time_converted2a
# 1282 entitytype10a
# 1283 entitytype11a
# 1284 entitytype12a
# 1285 segment_name1b
# 1286 segment_time_converted1b
# 1287 segment_narrative1b
# 1288 employee_id1
# 1289 justification_of_uof1
# 1290 employee_id2
# 1291 justification_of_uof2
# 1292 employee_id3
# 1293 justification_of_uof3
# 1294 employee_id4
# 1295 justification_of_uof4
# 1296 employee_id5
# 1297 justification_of_uof5
# 1298 employee_id6
# 1299 justification_of_uof6
# 1300 employee_id7
# 1301 justification_of_uof7
# 1302 employee_id8
# 1303 justification_of_uof8
# 1304 employee_id9
# 1305 justification_of_uof9
# 1306 employee_id10
# 1307 justification_of_uof10
# 1308 employee_id11
# 1309 justification_of_uof11
# 1310 employee_id12
# 1311 justification_of_uof12
# 1312 employee_id13
# 1313 justification_of_uof13
# 1314 employee_id14
# 1315 justification_of_uof14
# 1316 employee_id15
# 1317 justification_of_uof15
# 1318 employee_id16
# 1319 justification_of_uof16
# 1320 employee_id17
# 1321 justification_of_uof17
# 1322 employee_id18
# 1323 justification_of_uof18
# 1324 employee_id19
# 1325 justification_of_uof19
# 1326 employee_id20
# 1327 justification_of_uof20
# 1328 employee_id21
# 1329 justification_of_uof21
# 1330 employee_id22
# 1331 justification_of_uof22
# 1332 employee_id23
# 1333 justification_of_uof23
# 1334 employee_id24
# 1335 justification_of_uof24
# 1336 employee_id25
# 1337 justification_of_uof25
# 1338 employee_id26
# 1339 justification_of_uof26
# 1340 employee_id27
# 1341 justification_of_uof27
# 1342 employee_id28
# 1343 justification_of_uof28
# 1344 employee_id29
# 1345 justification_of_uof29
# 1346 employee_id30
# 1347 justification_of_uof30
# 1348 segment_name2
# 1349 segment_narrative2
# 1350 justification_for_uof1
# 1351 justification_for_uof2
# 1352 justification_for_uof3
# 1353 justification_for_uof4
# 1354 justification_for_uof5
# 1355 justification_for_uof6
# 1356 justification_for_uof7
# 1357 justification_for_uof8
# 1358 justification_for_uof9
# 1359 justification_for_uof10
# 1360 justification_for_uof11
# 1361 justification_for_uof12
# 1362 justification_for_uof13
# 1363 justification_for_uof14
# 1364 justification_for_uof15
# 1365 justification_for_uof16
# 1366 justification_for_uof17
# 1367 justification_for_uof18
# 1368 justification_for_uof19
# 1369 dob
# 1370 days1
# 1371 redomerge
# 1372 randomperson
# 1373 individualsearch
# 1374 totalpassengersearch
# 1375 totalpassengersearch2
# 1376 TS_reason
# 1377 frisk_likely
# 1378 frisk_omit
# 1379 ioars_stop
# 1380 bowman_stopcomments
# 1381 ioars_frisk
# 1382 bowman_friskcomments
# 1383 encountertypec
# 1384 encounterdate2a
# 1385 encounterdatetimec
# 1386 mni_fic
# 1387 call_noc
# 1388 call_no_origc
# 1389 callkeyc
# 1390 callkeynumc
# 1391 fi_officernumc
# 1392 finumc
# 1393 fi_personnumc
# 1394 naenumc
# 1395 fieldinterviewsc
# 1396 naepersonc
# 1397 fipersonc
# 1398 fiperson_idc
# 1399 tracspersonc
# 1400 cadonlypersonc
# 1401 aimonlypersonc
# 1402 warning_ord_desc62a
# 1403 warning_ord_number62a
# 1404 warning_statute_desc62a
# 1405 warning_statute_number62a
# 1406 calldatetimec
# 1407 rep_distc
# 1408 call_type_origc
# 1409 call_type_finalc
# 1410 created_datec
# 1411 call_created_timec
# 1412 groupc
# 1413 prior_suspect_descriptionc
# 1414 suspect_descriptionc
# 1415 search_performed_descriptionc
# 1416 uof_justificationc
# 1417 use_of_force_descriptionc
# 1418 fieldinterview_idc
# 1419 numberc
# 1420 stat3a
# 1421 documentformdisposition3a
# 1422 stat3b
# 1423 segment_time_converted2b
# 1424 stat3c
# 1425 segment_name1c
# 1426 segment_time_converted1c
# 1427 segment_narrative1c
# 1428 stat1
# 1429 documentformdisposition1
# 1430 stat2
# 1431 documentformdisposition2
# 1432 agencyagencyspace52
# 1433 agencyagencyspace62
# 1434 stat5
# 1435 documentformdisposition5
# 1436 justification_for_uof20
# 1437 justification_for_uof21
# 1438 justification_for_uof22
# 1439 justification_for_uof23
# 1440 justification_for_uof24
# 1441 justification_for_uof25
# 1442 justification_for_uof26
# 1443 justification_for_uof27
# 1444 justification_for_uof28
# 1445 justification_for_uof29
# 1446 justification_for_uof30
# 1447 stat4
# 1448 documentformdisposition4
# 1449 stat
# 1450 bowmancomments_stop
# 1451 bowmancomments_frisk
# 1452 reanalysistag
# 1453 unittotalpassengerssearched11a
# 1454 unittotalpassengerssearched21a
# 1455 unittotalpassengerssearched12a
# 1456 unittotalpassengerssearched22a
# 1457 warning_ord_desc19a
# 1458 warning_ord_number19a
# 1459 warning_statute_desc19a
# 1460 warning_statute_number19a
# 1461 rep_dist
# 1462 stat2a
# 1463 documentformdisposition2a
# 1464 force_type_descriptiona
# 1465 stat5a
# 1466 documentformdisposition5a
# 1467 force_type_descriptionb
# 1468 stat6
# 1469 documentformdisposition6
# 1470 stat8
# 1471 documentformdisposition8
# 1472 stat7
# 1473 documentformdisposition7
# 1474 startdate3
# 1475 search_performed_descriptiona
# 1476 search_performed_descriptionb
# 1477 dob2
# 1478 age2
# 1479 days2
# 1480 oldidentifier
# 1481 uniqueperson2
# 1482 idmatch
# 1483 encounterdatec
# 1484 incident_date1c
# 1485 incident_date2c
# 1486 incident_date3c
# 1487 incident_date4c
# 1488 incident_date5c
# 1489 incident_date6c
# 1490 dateofbirth3
# 1491 call_no_orig10
# 1492 call_no_orig11
# 1493 call_no_orig12
# 1494 unittotalpassengerssearched31a
# 1495 unittotalpassengerssearched13a
# 1496 unittotalpassengerssearched14a
# 1497 uof_report_number1c
# 1498 uof_report_number2c
# 1499 uof_report_number3c
# 1500 uof_report_number4c
# 1501 uof_report_number5c
# 1502 uof_report_number6c
# 1503 officer_activity1c
# 1504 officer_activity2c
# 1505 officer_activity3c
# 1506 officer_activity4c
# 1507 officer_activity5c
# 1508 officer_activity6c
# 1509 type_of_force1c
# 1510 type_of_force2c
# 1511 type_of_force3c
# 1512 type_of_force4c
# 1513 type_of_force5c
# 1514 type_of_force6c
# 1515 stat4a
# 1516 documentformdisposition4a
# 1517 stat8a
# 1518 documentformdisposition8a
# 1519 cad_numbera
# 1520 cad_numberb
# 1521 force_type_descriptionc
# 1522 districtnumber
# 1523 encountertime
# 1524 violation_typeb
# 1525 violmatch
# 1526 anyfrisk
# 1527 searchtype
# 1528 contrabandtype
# 1529 individualcontraband4a
# 1530 individualothercontraband4a
# 1531 vehiclecontraband21a
# 1532 vehiclecontraband31a
# 1533 vehiclecontraband41a
# 1534 vehiclecontraband22a
# 1535 vehiclecontraband32a
# 1536 vehiclecontraband42a
# 1537 vehiclecontraband23a
# 1538 vehiclecontraband33a
# 1539 vehiclecontraband43a
# 1540 vehiclecontraband14a
# 1541 vehiclecontraband24a
# 1542 vehiclecontraband34a
# 1543 vehiclecontraband44a
# 1544 vehicleothercontraband21a
# 1545 vehicleothercontraband31a
# 1546 vehicleothercontraband41a
# 1547 vehicleothercontraband22a
# 1548 vehicleothercontraband32a
# 1549 vehicleothercontraband42a
# 1550 vehicleothercontraband23a
# 1551 vehicleothercontraband33a
# 1552 vehicleothercontraband43a
# 1553 vehicleothercontraband14a
# 1554 vehicleothercontraband24a
# 1555 vehicleothercontraband34a
# 1556 vehicleothercontraband44a
# 1557 contrabandretrieved2
# 1558 contraitems
# 1559 sex_codeb
# 1560 sexmatch
# 1561 ethnicity_descriptionb
# 1562 age_codeb
# 1563 agematch
# 1564 searches1
# 1565 searches2
# 1566 searches3
# 1567 searches4
# 1568 searches5
# 1569 searches6
# 1570 searchbasis
# 1571 searches
# 1572 individualsearchbasis1a
# 1573 individualsearchbasis2a
# 1574 individualsearchbasis3a
# 1575 individualsearchbasis4a
# 1576 individualothersearchbasis1a
# 1577 individualothersearchbasis2a
# 1578 individualothersearchbasis3a
# 1579 individualothersearchbasis4a
# 1580 vehiclesearchbasis11a
# 1581 vehiclesearchbasis21a
# 1582 vehiclesearchbasis31a
# 1583 vehiclesearchbasis41a
# 1584 vehiclesearchbasis12a
# 1585 vehiclesearchbasis22a
# 1586 vehiclesearchbasis32a
# 1587 vehiclesearchbasis42a
# 1588 vehiclesearchbasis13a
# 1589 vehiclesearchbasis23a
# 1590 vehiclesearchbasis33a
# 1591 vehiclesearchbasis43a
# 1592 vehiclesearchbasis14a
# 1593 vehiclesearchbasis24a
# 1594 vehiclesearchbasis34a
# 1595 vehiclesearchbasis44a
# 1596 vehicleothersearchbasis11a
# 1597 vehicleothersearchbasis21a
# 1598 vehicleothersearchbasis31a
# 1599 vehicleothersearchbasis41a
# 1600 vehicleothersearchbasis12a
# 1601 vehicleothersearchbasis22a
# 1602 vehicleothersearchbasis32a
# 1603 vehicleothersearchbasis42a
# 1604 vehicleothersearchbasis13a
# 1605 vehicleothersearchbasis23a
# 1606 vehicleothersearchbasis33a
# 1607 vehicleothersearchbasis43a
# 1608 vehicleothersearchbasis14a
# 1609 vehicleothersearchbasis24a
# 1610 vehicleothersearchbasis34a
# 1611 vehicleothersearchbasis44a
# 1612 search_justificationc
# 1613 female
# 1614 white
# 1615 black
# 1616 latino
# 1617 otherrace
# 1618 old
# 1619 district1
# 1620 district2
# 1621 district3
# 1622 district4
# 1623 district5
# 1624 district6
# 1625 district7
# 1626 nonviolentstop
# 1627 violent_stop
# 1628 nosearch
# 1629 noincidentarrestsearch
# 1630 friskperf
# 1631 otherfrisk
# 1632 contrabandrecd
# 1633 inv20officers
# 1634 inv20units
# 1635 otheroutcome
# 1636 noaction_arrest
# 1637 racenew
# 1638 searchperf
# 1639 forciblefrisk
# 1640 arrest
# 1641 noaction
# 1642 timecat
# 1643 stopresult
# 1644 blackwhite
# 1645 latinowhite
# 1646 citation
# 1647 summons
# 1648 male
# 1649 young
# 1650 AI_AN_viccnt
# 1651 Asian_viccnt
# 1652 NH_PI_viccnt
# 1653 black_viccnt
# 1654 hispanic_viccnt
# 1655 other_viccnt
# 1656 white_viccnt
# 1657 white_peds
# 1658 black_peds
# 1659 hispanic_peds
# 1660 other_peds
# 1661 OBJECTID
# 1662 SYMBOL
# 1663 Neighbor_1
# 1664 SHAPE_STAr
# 1665 SHAPE_STLe
# 1666 geometry
# 1667 Population
# 1668 totalpop_avg
# 1669 white_avg
# 1670 black_avg
# 1671 asian_avg
# 1672 ai_an_avg
# 1673 nh_opi_avg
# 1674 otherrace_avg
# 1675 two_or_more_race_avg
# 1676 total_under5_avg
# 1677 total_5to9_avg
# 1678 total10to14_avg
# 1679 total_15to19_avg
# 1680 total_20to24_avg
# 1681 total_25to29_avg
# 1682 total_30to34_avg
# 1683 total_35to39_avg
# 1684 total_40to44_avg
# 1685 total_45to49_avg
# 1686 total_50to54_avg
# 1687 total_55to59_avg
# 1688 total_60to64_avg
# 1689 total_65to69_avg
# 1690 total_70to74_avg
# 1691 total_75to79_avg
# 1692 total_80to84_avg
# 1693 total_85andolder_avg
# 1694 total_under18_avg
# 1695 total_16andover_avg
# 1696 total_over18_avg
# 1697 totalmale_avg
# 1698 male_under5_avg
# 1699 male_5to9_avg
# 1700 male_10to14_avg
# 1701 male_15to19_avg
# 1702 male_20to24_avg
# 1703 male_25to29_avg
# 1704 male_30to34_avg
# 1705 male_35to39_avg
# 1706 male_40to44_avg
# 1707 male_45to49_avg
# 1708 male_50to54_avg
# 1709 male_55to59_avg
# 1710 male_60to64_avg
# 1711 male_65to69_avg
# 1712 male_70to74_avg
# 1713 male_75to79_avg
# 1714 male_80to84_avg
# 1715 male_85andover_avg
# 1716 male_under18_avg
# 1717 male_16andover_avg
# 1718 male_over18_avg
# 1719 totalfemale_avg
# 1720 female_under5_avg
# 1721 female_5to9_avg
# 1722 female_10to14_avg
# 1723 female_15to19_avg
# 1724 female_20to24_avg
# 1725 female_25to29_avg
# 1726 female_30to34_avg
# 1727 female_35to39_avg
# 1728 female_40to44_avg
# 1729 female_45to49_avg
# 1730 female_50to54_avg
# 1731 female_55to59_avg
# 1732 female_60to64_avg
# 1733 female_65to69_avg
# 1734 female_70to74_avg
# 1735 female_75to79_avg
# 1736 female_80to84_avg
# 1737 female_85andover_avg
# 1738 female_under18_avg
# 1739 female_16andover_avg
# 1740 female_over18_avg
# 1741 total_nothispanic_avg
# 1742 white_not_hisp_avg
# 1743 black_not_hisp_avg
# 1744 ai_an_not_hisp_avg
# 1745 asian_not_hisp_avg
# 1746 nh_opi_not_hisp_avg
# 1747 otherrace_not_hisp_avg
# 1748 two_or_more_race_not_hisp_avg
# 1749 total_hispanic_avg
# 1750 hispanic_white_avg
# 1751 hispanic_black_avg
# 1752 hispanic_ai_an_avg
# 1753 hispanic_asian_avg
# 1754 hispanic_nh_opi_avg
# 1755 hispanic_otherrace_avg
# 1756 hispanic_two_or_more_race_avg
# 1757 Labor Force Participation Rate
# 1758 Employment/Population Ratio
# 1759 Unemployment rate

# %%
def interest_summing(df, colnames):
    results = {}  

    for col in colnames:
        
        results[f"{col}_num"] = df.groupby('Neighborhood')[col].sum().reset_index()
    
    return results

# %% [markdown]
# #### Tidy up the df_ped_vic_count_neigh dataframe into ped_vic_neigh_count

# %%
col_keep = list(range(0, 23)) + list(range(28, 55)) + list(range(668, 671)) + list(range(1613, 1619)) + list(range(1626, 1760)) 

ped_vic_neigh_count = df_ped_vic_count_neigh.iloc[:, col_keep]
ped_vic_neigh_count.to_csv('ped_vic_neigh_count.csv', index = False)

# %%
col_printing(ped_vic_neigh_count)
# Out:
# 0 top10neighborhood
# 1 Neighborhood
# 2 searchperformed
# 3 pcsearch
# 4 incidentarrestsearch
# 5 contactdesc1a
# 6 stop_justificationa
# 7 stop_justificationb
# 8 search_justificationa
# 9 search_justificationb
# 10 uniqueperson
# 11 top20neighborhood
# 12 call_no
# 13 sexcat
# 14 racecat
# 15 agecat
# 16 agecontinuous
# 17 young_old
# 18 timeofday
# 19 morning
# 20 afternoon
# 21 firstevening
# 22 secondevening
# 23 district
# 24 stoptype
# 25 violentstop
# 26 violent_weapon
# 27 violent_other
# 28 propertystop
# 29 drugdealingstop
# 30 roadsafetystop
# 31 equipmentstop
# 32 publicdisorderstop
# 33 wantedorwarrantstop
# 34 trafficstop
# 35 possweaponstop
# 36 possdrugstop
# 37 otherstop
# 38 missingstop
# 39 violation_typea
# 40 searcharrest
# 41 searchnofrisk
# 42 friskperformed
# 43 searchandfrisk
# 44 frisktype
# 45 friskarrest
# 46 contrabandretrieved
# 47 stopoutcome
# 48 top20officer
# 49 top20unit
# 50 anysearch
# 51 search_nofrisk
# 52 friskandarrest
# 53 female
# 54 white
# 55 black
# 56 latino
# 57 otherrace
# 58 old
# 59 nonviolentstop
# 60 violent_stop
# 61 nosearch
# 62 noincidentarrestsearch
# 63 friskperf
# 64 otherfrisk
# 65 contrabandrecd
# 66 inv20officers
# 67 inv20units
# 68 otheroutcome
# 69 noaction_arrest
# 70 racenew
# 71 searchperf
# 72 forciblefrisk
# 73 arrest
# 74 noaction
# 75 timecat
# 76 stopresult
# 77 blackwhite
# 78 latinowhite
# 79 citation
# 80 summons
# 81 male
# 82 young
# 83 AI_AN_viccnt
# 84 Asian_viccnt
# 85 NH_PI_viccnt
# 86 black_viccnt
# 87 hispanic_viccnt
# 88 other_viccnt
# 89 white_viccnt
# 90 white_peds
# 91 black_peds
# 92 hispanic_peds
# 93 other_peds
# 94 OBJECTID
# 95 SYMBOL
# 96 Neighbor_1
# 97 SHAPE_STAr
# 98 SHAPE_STLe
# 99 geometry
# 100 Population
# 101 totalpop_avg
# 102 white_avg
# 103 black_avg
# 104 asian_avg
# 105 ai_an_avg
# 106 nh_opi_avg
# 107 otherrace_avg
# 108 two_or_more_race_avg
# 109 total_under5_avg
# 110 total_5to9_avg
# 111 total10to14_avg
# 112 total_15to19_avg
# 113 total_20to24_avg
# 114 total_25to29_avg
# 115 total_30to34_avg
# 116 total_35to39_avg
# 117 total_40to44_avg
# 118 total_45to49_avg
# 119 total_50to54_avg
# 120 total_55to59_avg
# 121 total_60to64_avg
# 122 total_65to69_avg
# 123 total_70to74_avg
# 124 total_75to79_avg
# 125 total_80to84_avg
# 126 total_85andolder_avg
# 127 total_under18_avg
# 128 total_16andover_avg
# 129 total_over18_avg
# 130 totalmale_avg
# 131 male_under5_avg
# 132 male_5to9_avg
# 133 male_10to14_avg
# 134 male_15to19_avg
# 135 male_20to24_avg
# 136 male_25to29_avg
# 137 male_30to34_avg
# 138 male_35to39_avg
# 139 male_40to44_avg
# 140 male_45to49_avg
# 141 male_50to54_avg
# 142 male_55to59_avg
# 143 male_60to64_avg
# 144 male_65to69_avg
# 145 male_70to74_avg
# 146 male_75to79_avg
# 147 male_80to84_avg
# 148 male_85andover_avg
# 149 male_under18_avg
# 150 male_16andover_avg
# 151 male_over18_avg
# 152 totalfemale_avg
# 153 female_under5_avg
# 154 female_5to9_avg
# 155 female_10to14_avg
# 156 female_15to19_avg
# 157 female_20to24_avg
# 158 female_25to29_avg
# 159 female_30to34_avg
# 160 female_35to39_avg
# 161 female_40to44_avg
# 162 female_45to49_avg
# 163 female_50to54_avg
# 164 female_55to59_avg
# 165 female_60to64_avg
# 166 female_65to69_avg
# 167 female_70to74_avg
# 168 female_75to79_avg
# 169 female_80to84_avg
# 170 female_85andover_avg
# 171 female_under18_avg
# 172 female_16andover_avg
# 173 female_over18_avg
# 174 total_nothispanic_avg
# 175 white_not_hisp_avg
# 176 black_not_hisp_avg
# 177 ai_an_not_hisp_avg
# 178 asian_not_hisp_avg
# 179 nh_opi_not_hisp_avg
# 180 otherrace_not_hisp_avg
# 181 two_or_more_race_not_hisp_avg
# 182 total_hispanic_avg
# 183 hispanic_white_avg
# 184 hispanic_black_avg
# 185 hispanic_ai_an_avg
# 186 hispanic_asian_avg
# 187 hispanic_nh_opi_avg
# 188 hispanic_otherrace_avg
# 189 hispanic_two_or_more_race_avg
# 190 Labor Force Participation Rate
# 191 Employment/Population Ratio
# 192 Unemployment rate

# %% [markdown]
# ### Adding More Variables into ped_vic_neigh_count
# Variables like:
# - totalvictims - total_viccnt - (AI_AN_viccnt, Asian_viccnt, NH_PI_viccnt, black_viccnt, hispanic_viccnt, other_viccnt, white_viccnt)
# - totalblackwhite_pedstops (white_peds + black_peds)
# - black stop rate (black stops/black+white stops)
# - white stop rate (white stops/black+white stops)
# - population proportion of black individuals (black population/totalpopulation)
# - population proportion of white individuals (white population/totalpopulation)
# - black_ped_DI (black stop rate/population proportion of black individuals)
# - white_ped_DI (white stop rate/population proportion of white individuals)

# %% [markdown]
# ##### Calculating total victims

# %%
victimgrps = ['AI_AN_viccnt', 'Asian_viccnt', 'NH_PI_viccnt', 'black_viccnt', 'hispanic_viccnt', 'other_viccnt', 'white_viccnt']
race_vic_neigh['total_viccnt'] = race_vic_neigh[victimgrps].sum(axis = 1)
race_vic_neigh.head()
# Out:
# Race-Ethnicity       Neighborhood  AI_AN_viccnt  Asian_viccnt  NH_PI_viccnt  \
# 0                     alcott park             0             0             0
# 1                         alverno             0             0             0
# 2                           amani             2             0             0
# 3               arlington gardens             0             1             0
# 4               arlington heights             2             5             0
#
# Race-Ethnicity  black_viccnt  hispanic_viccnt  other_viccnt  white_viccnt  \
# 0                          3                0             0             3
# 1                          4                7             0            12
# 2                        262                6             0            10
# 3                        114                6             0            23
# 4                        539               14             0            46
#
# Race-Ethnicity  total_viccnt
# 0                          6
# 1                         23
# 2                        280
# 3                        144
# 4                        606

# %% [markdown]
# ##### Calculating black and white victimization rates

# %%
race_vic_neigh['black_vicrate'] = race_vic_neigh['black_viccnt'] / race_vic_neigh['total_viccnt']
race_vic_neigh['white_vicrate'] = race_vic_neigh['white_viccnt'] / race_vic_neigh['total_viccnt']

# %%
# subset race_vic_neigh to a smaller df for merging later on
vic_info = race_vic_neigh[['black_vicrate', 'white_vicrate', 'total_viccnt', 'Neighborhood']]

# %% [markdown]
# ##### Calculating stop rates for Black and White pedestrians

# %%
# recode racecat so that missing = NA
racecat_missing = {'missing' : np.nan}
df_enc['racecat'] = df_enc['racecat'].replace(racecat_missing)
df_ped['racecat'] = df_ped['racecat'].replace(racecat_missing)

# Creating a pivot table that lets us see the counts of vehicle stops by race by neighborhood
encneighrace_pivot = df_enc.pivot_table(
    index='Neighborhood',   # Rows (neighborhoods)
    columns='racecat',      # Columns (races)
    aggfunc='size',         # Count occurrences
    fill_value=0            # Replace NaNs with 0s
)

encneighrace_pivot = encneighrace_pivot.reset_index()

# Creating a pivot table that lets us see the counts of pedestrian stops by race by neighborhood
pedneighrace_pivot = df_ped.pivot_table(
    index='Neighborhood',   # Rows (neighborhoods)
    columns='racecat',      # Columns (races)
    aggfunc='size',         # Count occurrences
    fill_value=0            # Replace NaNs with 0s
)

pedneighrace_pivot = pedneighrace_pivot.reset_index()

# merge pedneighrace_pivot into neighborhood_vicsus_est
neighborhood_vicsus_pedenc_final = pd.merge(neighborhood_vicsus_est, pedneighrace_pivot, on = 'Neighborhood', how = 'inner')

# rename the pedestrian columns
neighborhood_vicsus_pedenc_final = neighborhood_vicsus_pedenc_final.rename(columns = {'white' : 'white_pedstops',
                                                                                      'black' : 'black_pedstops',
                                                                                      'latinx' : 'latinx_pedstops',
                                                                                      'other' : 'other_pedstops'})

# merge encneighrace_pivot into neighborhood_vicsus_pedenc_final
neighborhood_vicsus_pedenc_final = pd.merge(neighborhood_vicsus_pedenc_final, encneighrace_pivot, on = 'Neighborhood', how = 'inner')

# rename the vehicle columns
neighborhood_vicsus_pedenc_final = neighborhood_vicsus_pedenc_final.rename(columns = {'white' : 'white_vehstops',
                                                                                      'black' : 'black_vehstops',
                                                                                      'latinx' : 'latinx_vehstops',
                                                                                      'other' : 'other_vehstops'})
# Out:
# C:\Users\michelle.iolow\AppData\Local\Temp\ipykernel_54720\2272365407.py:7: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   encneighrace_pivot = df_enc.pivot_table(
# C:\Users\michelle.iolow\AppData\Local\Temp\ipykernel_54720\2272365407.py:17: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pedneighrace_pivot = df_ped.pivot_table(

# %%
new_ped_df = neighborhood_vicsus_pedenc_final.copy()

pedgrps = ['white_pedstops', 'black_pedstops']
# creating a variable that has the total pedestrian stops for black and white people
new_ped_df['black_white_total_pedstops'] = new_ped_df[pedgrps].sum(axis = 1)

# calculating white and black stop rate
new_ped_df['white_ped_stoprate'] = new_ped_df['white_pedstops']/new_ped_df['black_white_total_pedstops']
new_ped_df['black_ped_stoprate'] = new_ped_df['black_pedstops']/new_ped_df['black_white_total_pedstops']

# subset this dataframe for merging later
new_ped_df = new_ped_df[['white_ped_stoprate', 'black_ped_stoprate', 'black_white_total_pedstops', 'Neighborhood']]

# %% [markdown]
# ##### Calculating Population Proportion for Black and White folks by neighborhood

# %%
new_pop_df = neighborhood_vicsus_pedenc_final.copy()

popgrps = ['white_avg', 'black_avg', 'asian_avg', 'ai_an_avg', 'nh_opi_avg', 'otherrace_avg', 'two_or_more_race_avg']
# creating a variable that has the total population count for each neighborhood
new_pop_df['totalpopulation_count'] = new_pop_df[popgrps].sum(axis = 1)

# calculating population proportion for white and black individuals in different neighborhood
new_pop_df['blackpop_prop'] = new_pop_df['black_avg']/new_pop_df['totalpopulation_count']
new_pop_df['whitepop_prop'] = new_pop_df['white_avg']/new_pop_df['totalpopulation_count']

# subset this dataframe for merging later
new_pop_df = new_pop_df[['totalpopulation_count', 'blackpop_prop', 'whitepop_prop', 'Neighborhood']]

# %% [markdown]
# ### Calculating the non-RAD Disparity Index for Pedestrian Stops
# This is stop rate of a given group divided population proportion of that given group

# %%
disparity_ped_df = pd.merge(new_ped_df, vic_info, on = 'Neighborhood', how = 'inner')
disparity_ped_df = pd.merge(disparity_ped_df, new_pop_df, on = 'Neighborhood', how = 'inner')

# %%
col_printing(disparity_ped_df)
# Out:
# 0 white_ped_stoprate
# 1 black_ped_stoprate
# 2 black_white_total_pedstops
# 3 Neighborhood
# 4 black_vicrate
# 5 white_vicrate
# 6 total_viccnt
# 7 totalpopulation_count
# 8 blackpop_prop
# 9 whitepop_prop

# %%
disparity_ped_df['black_ped_DI'] = disparity_ped_df['black_ped_stoprate'] / disparity_ped_df['blackpop_prop']
disparity_ped_df['white_ped_DI'] = disparity_ped_df['white_ped_stoprate'] / disparity_ped_df['whitepop_prop']

# %% [markdown]
# ## Merging disparity information into our pedestrian dataframe (ped_vic_neigh_count)

# %%
PedestrianRegression_df = pd.merge(ped_vic_neigh_count, disparity_ped_df, on = 'Neighborhood', how = 'inner')
PedestrianRegression_df.to_csv("PedestrianRegression_df.csv", index = False)

# %% [markdown]
# # RAD Index Dataframe Construction

# %%
# from neighborhood_vicsus_pedenc_est, pull 'white_not_hisp_avg', 'black_not_hisp_avg', 'totalpop_avg'
popcount = neighborhood_vicsus_pedenc_est[['Neighborhood', 'white_not_hisp_avg', 'black_not_hisp_avg', 'totalpop_avg']]

# %%
# pull victim counts for black and white
race_vic_neigh2 = race_vic_neigh.copy()

total_interest = ['AI_AN_viccnt', 'Asian_viccnt', 'NH_PI_viccnt', 'black_viccnt', 'hispanic_viccnt', 'other_viccnt', 'white_viccnt']

# Calculate total_viccnt and add it to the DataFrame
race_vic_neigh2['total_viccnt'] = race_vic_neigh2[total_interest].sum(axis = 1)
vic_interest2 = ['black_viccnt', 'white_viccnt', 'total_viccnt']

results = interest(race_vic_neigh2, vic_interest2)

# Access the results by column name
white_df = results['white_viccnt_num']
black_df = results['black_viccnt_num']
total_df = results['total_viccnt_num']

vic_df2 = pd.merge(white_df, black_df, on = 'Neighborhood', how = 'outer')
vic_df2 = pd.merge(vic_df2, total_df, on = 'Neighborhood', how = 'outer')

# %%
# pull pedestrian counts for black and white
ped_interest = ['white_peds', 'black_peds']
results = interest(race_count_neigh, ped_interest)

# Access the results by column name
whiteped_df = results['white_peds_num']
blackped_df = results['black_peds_num']

pedinterest_df2 = pd.merge(whiteped_df, blackped_df, on = 'Neighborhood', how = 'outer')

# %% [markdown]
# #### Merge pedinterest_df2 with vic_df2 with popcount

# %%
result_RAD = pd.merge(popcount, vic_df2, on = 'Neighborhood', how = 'inner')
result_RAD= pd.merge(result_RAD, pedinterest_df2, on = 'Neighborhood', how = 'outer')

# %%
# Creating a percentage column for Total White Population and Total Black population
result_RAD['percent_whitepop'] = (result_RAD['white_not_hisp_avg'] / result_RAD['totalpop_avg']) * 100
result_RAD['percent_blackpop'] = (result_RAD['black_not_hisp_avg'] / result_RAD['totalpop_avg']) * 100

# %%
result_RAD.to_csv('RAD_Ped_df.csv', index = False)

# %% [markdown]
# # New Dataframe with Vehicles as the Unit of Analysis (df_enc)

# %% [markdown]
# ### Creating a count of vehicle stops by race in the df_enc dataframe

# %%
# Use cat.rename_categories to rename 'missing' to NaN
# df_enc['racecat'] = df_enc['racecat'].cat.remove_categories('missing')

race_count_enc = df_enc.pivot_table(index = 'Neighborhood', columns = 'racecat', aggfunc = 'size', fill_value = 0, observed = True)

race_count_enc = race_count_enc.rename(columns = {'white' : 'vehlvl_white', 'black' : 'vehlvl_black',
                                                      'latinx' : 'vehlvl_hispanic', 
                                                      'other' : 'vehlvl_other'})

# Reset the index so that 'neighborhood' becomes a column
race_count_enc = race_count_enc.reset_index()

# %% [markdown]
# ##### Merge the race_count_enc and race_vic_neigh dataframe together

# %%
vic_enc_count = pd.merge(race_vic_neigh, race_count_enc, on = 'Neighborhood', how = 'inner')

# %%
print(len(vic_enc_count))
print(len(df_enc))
# Out:
# 184
# 56226

# %%
vic_enc_count['Neighborhood']
# Out:
# 0                     alcott park
# 1                         alverno
# 2                           amani
# 3               arlington gardens
# 4               arlington heights
# 5                    avenues west
# 6                      baran park
# 7                        bay view
# 8               bluemound heights
# 9                  borchert field
# 10                bradley estates
# 11                  brewer's hill
# 12                       brynwood
# 13                   burnham park
# 14                  calumet farms
# 15              cambridge heights
# 16                    cannon park
# 17                capitol heights
# 18                   castle manor
# 19                  clarke square
# 20                  clayton crest
# 21              clock tower acres
# 22               cold spring park
# 23                college heights
# 24                  columbus park
# 25                      concordia
# 26                    cooper park
# 27                copernicus park
# 28                    dineen park
# 29                   downer woods
# 30                   dretzka park
# 31                   enderis park
# 32                 estabrook park
# 33                    euclid park
# 34                      fair park
# 35                      fairfield
# 36                       fairview
# 37                       fernwood
# 38              florist highlands
# 39              forest home hills
# 40               franklin heights
# 41                   garden homes
# 42                    golden gate
# 43                  golden valley
# 44                   goldman park
# 45                        gra-ram
# 46                      graceland
# 47                       grantosa
# 48              granville station
# 49                granville woods
# 50                 grasslyn manor
# 51                     green moor
# 52                 grover heights
# 53                   halyard park
# 54                hampton heights
# 55                       harambee
# 56                    harbor view
# 57                  harder's oaks
# 58                     havenwoods
# 59                   hawley farms
# 60                 hawthorne glen
# 61                      haymarket
# 62               heritage heights
# 63               highwood estates
# 64                       hillside
# 65                 hilltop parish
# 66       historic mitchell street
# 67            historic third ward
# 68                    holler park
# 69              honey creek manor
# 70            honey creek parkway
# 71                   jackson park
# 72                johnson's woods
# 73                    juneau town
# 74                  kilbourn town
# 75                      king park
# 76                      kops park
# 77                      lake park
# 78                      land bank
# 79                    layton park
# 80                  lenox heights
# 81                  lincoln creek
# 82                   lincoln park
# 83                lincoln village
# 84                   lindsay park
# 85       little menomonee parkway
# 86                      long view
# 87                lower east side
# 88                     lyons park
# 89                     mack acres
# 90                  maitland park
# 91                     maple tree
# 92                      marquette
# 93                   martin drive
# 94                 mc govern park
# 95                    melody view
# 96          menomonee river hills
# 97     menomonee river hills east
# 98         menomonee river valley
# 99                   merrill park
# 100                 metcalfe park
# 101                       midtown
# 102                   mill valley
# 103                 miller valley
# 104                mitchell field
# 105                 mitchell park
# 106                 mitchell west
# 107                morgan heights
# 108                    morgandale
# 109                    mount mary
# 110                  mount olivet
# 111                   murray hill
# 112                   muskego way
# 113                     nash park
# 114                 national park
# 115                     new coeln
# 116                north division
# 117               north granville
# 118                    northpoint
# 119                    northridge
# 120              northridge lakes
# 121           old north milwaukee
# 122                    park knoll
# 123                    park place
# 124                     park view
# 125                 parkway hills
# 126                  pheasant run
# 127               pollber heights
# 128                       polonia
# 129               red oak heights
# 130                     ridgeview
# 131                    river bend
# 132                riverside park
# 133              riverton heights
# 134                     riverwest
# 135                 rolling green
# 136               roosevelt grove
# 137                    root creek
# 138                    rufus king
# 139                  saint joseph
# 140                 saveland park
# 141                  schlitz park
# 142                 servite woods
# 143                  sherman park
# 144                   silver city
# 145                 silver spring
# 146                   silver swan
# 147                     southgate
# 148                    southpoint
# 149                 st. amelian's
# 150                    story hill
# 151                sunset heights
# 152        the valley / pigsville
# 153                thurston woods
# 154             timmerman airport
# 155                timmerman west
# 156                    tippecanoe
# 157          town & country manor
# 158                  town of lake
# 159                      triangle
# 160                triangle north
# 161                  tripoli park
# 162               upper east side
# 163                        uptown
# 164                      valhalla
# 165                  valley forge
# 166              veterans affairs
# 167                    vogel park
# 168                     wahl park
# 169                walker's point
# 170                   walnut hill
# 171            washington heights
# 172               washington park
# 173                     wedgewood
# 174                     west view
# 175              whispering hills
# 176                   white manor
# 177                    wick field
# 178                  williamsburg
# 179                   wilson park
# 180                woodland court
# 181                     woodlands
# 182                   wyrick park
# 183                   yankee hill
# Name: Neighborhood, dtype: object

# %% [markdown]
# ## Forming the vehicles df with victim counts and pedestrian counts

# %%
df_enc_vic_count = pd.merge(df_enc, vic_enc_count, on = 'Neighborhood', how = 'inner')
df_enc_vic_count.to_csv("df_enc_vic_count.csv", index = False)

# %% [markdown]
# ## Forming the vehicles df (unit of analysis) with victim counts, pedestrian counts, and neighborhood details

# %%
neighborhood_estimates = neighborhood_estimates.rename(columns = {'Neighborho' : 'Neighborhood'})
# Convert the 'Neighborhood' column to string values and then apply string methods
neighborhood_estimates['Neighborhood'] = neighborhood_estimates['Neighborhood'].fillna('').apply(str)
neighborhood_estimates['Neighborhood'] = neighborhood_estimates['Neighborhood'].str.strip().str.lower()

# %%
neighborhood_vicsus_est = neighborhood_vicsus_est.rename(columns = {'Neighborho' : 'Neighborhood'})
# Convert the 'Neighborhood' column to string values and then apply string methods
neighborhood_vicsus_est['Neighborhood'] = neighborhood_vicsus_est['Neighborhood'].fillna('').apply(str)
neighborhood_vicsus_est['Neighborhood'] = neighborhood_vicsus_est['Neighborhood'].str.strip().str.lower()

df_enc_vic_count_neigh = pd.merge(df_enc_vic_count, neighborhood_vicsus_est, on = 'Neighborhood', how = 'inner')
df_enc_vic_count_neigh.to_csv("enc_vic_count_neigh.csv", index = False)

# %% [markdown]
# #### Tidy up df_enc_vic_count into enc_vic_neigh_count

# %%
col_keep = list(range(0, 2)) + list(range(43, 45)) + list(range(55, 65)) + list(range(109, 117)) + list(range(130, 134)) + list(range(139, 146)) + list(range(1555, 1560)) + list(range(1812, 1822)) + list(range(1831, 1842)) + list(range(1849, 2074))
enc_vic_count_neigh = df_enc_vic_count_neigh.iloc[:, col_keep]
enc_vic_count_neigh.to_csv('enc_vic_count_neigh.csv', index = False)

# %% [markdown]
# ### Adding More Variables into enc_vic_count_neigh
# Variables like:
# - totalvictims - total_viccnt - (AI_AN_viccnt, Asian_viccnt, NH_PI_viccnt, black_viccnt, hispanic_viccnt, other_viccnt, white_viccnt)
# - totalblackwhite_vehstops (white_vehs + black_vehs)
# - black stop rate (black stops/black+white stops)
# - white stop rate (white stops/black+white stops)
# - population proportion of black individuals (black population/totalpopulation)
# - population proportion of white individuals (white population/totalpopulation)
# - black_veh_DI (black stop rate/population proportion of black individuals)
# - white_veh_DI (white stop rate/population proportion of white individuals)

# %% [markdown]
# total victim count and black and white victimization rates are available in vic_info from calculations above

# %% [markdown]
# ##### Calculating stop rates for Black and White driven vehicles

# %%
new_veh_df = neighborhood_vicsus_pedenc_final.copy()

vehgrps = ['white_vehstops', 'black_vehstops']
# creating a variable that has the total pedestrian stops for black and white people
new_veh_df['black_white_total_vehstops'] = new_veh_df[vehgrps].sum(axis = 1)

# calculating white and black stop rate
new_veh_df['white_veh_stoprate'] = new_veh_df['white_vehstops']/new_veh_df['black_white_total_vehstops']
new_veh_df['black_veh_stoprate'] = new_veh_df['black_vehstops']/new_veh_df['black_white_total_vehstops']

# subset this dataframe for merging later
new_veh_df = new_veh_df[['white_veh_stoprate', 'black_veh_stoprate', 'black_white_total_vehstops', 'Neighborhood']]

# %% [markdown]
# ##### Calculating Population Proportion for Black and White folks by neighborhood
# This was already done above. It is in the df, new_pop_df

# %% [markdown]
# ### Calculating the non-RAD Disparity Index for Vehicle Stops
# This is stop rate of a given group divided population proportion of that given group

# %%
disparity_veh_df = pd.merge(new_veh_df, vic_info, on = 'Neighborhood', how = 'inner')
disparity_veh_df = pd.merge(disparity_veh_df, new_pop_df, on = 'Neighborhood', how = 'inner')

# %% [markdown]
# ## Merging disparity information into our pedestrian dataframe (enc_vic_neigh_count)

# %%
VehicleRegression_df = pd.merge(enc_vic_count_neigh, disparity_veh_df, on = 'Neighborhood', how = 'inner')
VehicleRegression_df.to_csv("VehicleRegression_df.csv", index = False)
